# %% [markdown]
# # Sentimental Test
# This notebook is used to test the sentiment analysis pipeline.

# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
import numpy as np
import spacy
from checklist.test_suite import TestSuite
from checklist.perturb import Perturb
from transformers import pipeline

# %%
# use pipeline sentimental analysis
model = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\kafka\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# used to decrease size of chunk
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# use to process the data with the sentimental model
def batch_predict(model, data, batch_size=128):
    ret = []
    for d in chunks(data, batch_size):
        ret.extend(model(d))
    return ret

# %%
import numpy as np


# Function to check the score
# I am not sure about the score that author has calculated.
def pred_and_conf(data):
    # change format to softmax, make everything in [0.33, 0.66] range be predicted as neutral
    preds = batch_predict(model, data)
    pr = np.array([x['score'] if x['label'] == 'POSITIVE' else 1 - x['score'] for x in preds])
    pp = np.zeros((pr.shape[0], 3))
    margin_neutral = 1/3.
    mn = margin_neutral / 2.
    neg = pr < 0.5 - mn
    pp[neg, 0] = 1 - pr[neg]
    pp[neg, 2] = pr[neg]
    pos = pr > 0.5 + mn
    pp[pos, 0] = 1 - pr[pos]
    pp[pos, 2] = pr[pos]
    neutral_pos = (pr >= 0.5) * (pr < 0.5 + mn)
    pp[neutral_pos, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_pos] - 0.5)
    pp[neutral_pos, 2] = 1 - pp[neutral_pos, 1]
    neutral_neg = (pr < 0.5) * (pr > 0.5 - mn)
    pp[neutral_neg, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_neg] - 0.5)
    pp[neutral_neg, 0] = 1 - pp[neutral_neg, 1]
    preds = np.argmax(pp, axis=1)
    return preds, pp

# %%
suite_path = 'sentiment_suite_dt1.pkl' #identify suite path name
suite = TestSuite.from_file(suite_path)

# %%
suite.run(pred_and_conf, n=500) # run the test suite with 500 samples and check score with `pred_and_conf` function
# Out:
# Running single positive words
# Predicting 36 examples
# Running single negative words
# Predicting 35 examples
# Running single neutral words
# Predicting 13 examples
# Running Sentiment-laden words in context
# Predicting 500 examples
# Running neutral words in context
# Predicting 500 examples
# Running intensifiers
# Predicting 1000 examples
# Running reducers
# Predicting 1000 examples
# Running change neutral words with BERT
# Predicting 205 examples
# Running add positive phrases
# Predicting 5500 examples
# Running add negative phrases
# Predicting 5500 examples
# Running punctuation
# Predicting 1105 examples
# Running typos
# Predicting 1000 examples
# Running 2 typos
# Predicting 1000 examples
# Running contractions
# Predicting 1182 examples
# Running used to, but now
# Predicting 500 examples
# Running "used to" should reduce
# Predicting 1000 examples
# Running protected: race
# Predicting 2000 examples
# Running protected: sexual
# Predicting 7000 examples
# Running protected: religion
# Predicting 11000 examples
# Running protected: nationality
# Predicting 10000 examples
# Running protected: country
# Predicting 98500 examples
# Running simple negations: negative
# Predicting 500 examples
# Running simple negations: not negative
# Predicting 500 examples
# Running simple negations: not neutral is still neutral
# Predicting 500 examples
# Running simple negations: I thought x was positive, but it was not (should be negative)
# Predicting 500 examples
# Running simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Predicting 500 examples
# Running simple negations: but it was not (neutral) should still be neutral
# Predicting 500 examples
# Running Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Predicting 500 examples
# Running Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Predicting 500 examples
# Running negation of neutral with neutral in the middle, should still neutral
# Predicting 500 examples
# Running my opinion is what matters
# Predicting 500 examples
# Running Q & A: yes
# Predicting 500 examples
# Running Q & A: yes (neutral)
# Predicting 500 examples
# Running Q & A: no
# Predicting 500 examples
# Running Q & A: no (neutral)
# Predicting 500 examples

# %%
suite.summary() #summary the test case
# Out:
# Vocabulary
#
# single positive words
# Test cases:      36
# Fails (rate):    0 (0.0%)
#
#
# single negative words
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.3 0.0 0.7 average
# ----
#
#
# single neutral words
# Test cases:      13
# Fails (rate):    13 (100.0%)
#
# Example fails:
# 0.0 0.0 1.0 Italian
# ----
# 0.0 0.0 1.0 saw
# ----
# 0.0 0.0 1.0 Australian
# ----
#
#
# Sentiment-laden words in context
# Test cases:      28980
# Test cases run:  500
# Fails (rate):    11 (2.2%)
#
# Example fails:
# 0.0 0.0 1.0 That realistic is average.
# ----
# 0.9 0.0 0.1 It was a well remale.
# ----
# 0.0 1.0 0.0 This is a weird smartwatch.
# ----
#
#
# neutral words in context
# Test cases:      5544
# Test cases run:  500
# Fails (rate):    474 (94.8%)
#
# Example fails:
# 0.0 0.0 1.0 That mystery was Australian.
# ----
# 0.0 0.0 1.0 I find that shoes.
# ----
# 1.0 0.0 0.0 That action movie was Israeli.
# ----
#
#
# intensifiers
# Test cases:      2000
# Test cases run:  500
# After filtering: 497 (99.4%)
# Fails (rate):    11 (2.2%)
#
# Example fails:
# 1.0 0.0 0.0 This is an average cartoon.
# 0.0 0.0 1.0 This is an amazingly average cartoon.
#
# ----
# 1.0 0.0 0.0 This is a hard musical.
# 0.0 0.0 1.0 This is an amazingly hard musical.
#
# ----
# 0.9 0.0 0.1 I abhor that war.
# 0.7 0.0 0.3 I truly abhor that war.
#
# ----
#
#
# reducers
# Test cases:      2000
# Test cases run:  500
# After filtering: 0 (0.0%)
#
#
# change neutral words with BERT
# Test cases:      20
# Fails (rate):    1 (5.0%)
#
# Example fails:
# 0.1 0.0 0.9 Best Value for the $$$ Easy to put together. Came with very good and clearcut instructions.You have to have a good amount of floor space for it to turn though.Other than that it is a super buy!!!
# 0.9 0.0 0.1 Best Value for the $$$ Easy to put together. Came with very good and clearcut instructions.You need to need a good amount of floor space for it to turn though.Other than that it is a super buy!!!
# 0.9 0.0 0.1 Best Value for the $$$ Easy to put together. Came with very good and clearcut instructions.You need to need a good amount of floor space for it to turn though.Other than that it is a super buy!!!
#
# ----
#
#
# add positive phrases
# Test cases:      500
# Fails (rate):    13 (2.6%)
#
# Example fails:
# 0.1 0.0 0.9 Beware: NO 5th BOOK! The Everyman's Library version is abridged -- without being advertised as so, either on Amazon OR anywhere inside the book!The Wealth of Nations is a pivotal work in the history of economics and human nature, but you'd be better off finding an edition that includes the entire work.The Wealth of Nations (Everyman's Library)
# 0.0 0.7 0.3 Beware: NO 5th BOOK! The Everyman's Library version is abridged -- without being advertised as so, either on Amazon OR anywhere inside the book!The Wealth of Nations is a pivotal work in the history of economics and human nature, but you'd be better off finding an edition that includes the entire work.The Wealth of Nations (Everyman's Library. I would purchase product again.
#
# ----
# 0.1 0.0 0.9 can't handle browser idle time (poor support) Installation was easy and everything looked great. Until I tried to access the internet via my browser the next morning ("page cannot be displayed"). All ideas of the helpdesk how to fix it didn't change anything (we exchanged about 20 emails) so that they agreed it was a hardware problem. I returned it and got the next one with the same problem. The answer of the helpdesk this time: don't use ZoneAlarm. And if this is not the problem, then it must be Windows XP. Unfortunately, shutting down ZoneAlarm didn't fix the problem. So the problem must be Windows XP in their opinion. That's an easy excuse because nobody can prove anything and I got stuck with my router and my problem. So I returned it.Conclusion: if you have a dial-up connection and don't stay connected while being idle, this is a good product. If you have a cable modem and don't shut down your computer all the time, try a different router.
# 0.2 0.0 0.8 can't handle browser idle time (poor support) Installation was easy and everything looked great. Until I tried to access the internet via my browser the next morning ("page cannot be displayed"). All ideas of the helpdesk how to fix it didn't change anything (we exchanged about 20 emails) so that they agreed it was a hardware problem. I returned it and got the next one with the same problem. The answer of the helpdesk this time: don't use ZoneAlarm. And if this is not the problem, then it must be Windows XP. Unfortunately, shutting down ZoneAlarm didn't fix the problem. So the problem must be Windows XP in their opinion. That's an easy excuse because nobody can prove anything and I got stuck with my router and my problem. So I returned it.Conclusion: if you have a dial-up connection and don't stay connected while being idle, this is a good product. If you have a cable modem and don't shut down your computer all the time, try a different router. I would purchase product again.
#
# ----
# 0.1 0.9 0.0 Ooooooh my Godddddddddd !!! Like most of Betty Carter's albums, this one demands patience, attention, availability. You cannnot appreciate HER music if you want to discover all the riches at once. If you're a man, you got to be a gentleman. It's been three days now that I keep listening to "It's not about the melody". I did not want to talk about it, because it's so beautiful... You know what I mean? It's a bit like when you got a beautiful girlfriend, you're not going to yell at everybody that you've got a beautiful girl friend, are you?... See what I mean? ... Huh, what did I say? nothing. OK, I must be going now........
# 0.9 0.0 0.1 Ooooooh my Godddddddddd !!! Like most of Betty Carter's albums, this one demands patience, attention, availability. You cannnot appreciate HER music if you want to discover all the riches at once. If you're a man, you got to be a gentleman. It's been three days now that I keep listening to "It's not about the melody". I did not want to talk about it, because it's so beautiful... You know what I mean? It's a bit like when you got a beautiful girlfriend, you're not going to yell at everybody that you've got a beautiful girl friend, are you?... See what I mean? ... Huh, what did I say? nothing. OK, I must be going now. I would purchase product again.
#
# ----
#
#
# add negative phrases
# Test cases:      500
# Fails (rate):    2 (0.4%)
#
# Example fails:
# 0.9 0.0 0.1 Fahrenheit 451 I read this book as a teenager, and I wanted my students to read it as well. Although I loved it, I did not get the same reaction as when they saw the video. However they did think the video was cheesy... :D
# 0.8 0.0 0.2 Fahrenheit 451 I read this book as a teenager, and I wanted my students to read it as well. Although I loved it, I did not get the same reaction as when they saw the video. However they did think the video was cheesy. Never purchasing this product again.
#
# ----
# 0.0 0.8 0.2 How to Handcolor like a Hallmark Artist. This book is great if you want to stick to only one medium, Marshall Photo Oils. The examples are sappy and saccharine.Cutesy kids, flowers, bla bla bla! This book copies the style and explanations of Handcoloring Photographs Step by Step by Laird. Thats because Dorskind has nothing to say herself and doesn't know how to explain. Now you should buy the book by Laird. I, like most reviewers recommend it strongly. I also highly recommend to you Handtinting Photographs. Buy this book too. Don't buy Dorskind's book. Its a waste of money.
# 0.0 0.0 1.0 How to Handcolor like a Hallmark Artist. This book is great if you want to stick to only one medium, Marshall Photo Oils. The examples are sappy and saccharine.Cutesy kids, flowers, bla bla bla! This book copies the style and explanations of Handcoloring Photographs Step by Step by Laird. Thats because Dorskind has nothing to say herself and doesn't know how to explain. Now you should buy the book by Laird. I, like most reviewers recommend it strongly. I also highly recommend to you Handtinting Photographs. Buy this book too. Don't buy Dorskind's book. Its a waste of money. I hate product.
# 0.1 0.0 0.9 How to Handcolor like a Hallmark Artist. This book is great if you want to stick to only one medium, Marshall Photo Oils. The examples are sappy and saccharine.Cutesy kids, flowers, bla bla bla! This book copies the style and explanations of Handcoloring Photographs Step by Step by Laird. Thats because Dorskind has nothing to say herself and doesn't know how to explain. Now you should buy the book by Laird. I, like most reviewers recommend it strongly. I also highly recommend to you Handtinting Photographs. Buy this book too. Don't buy Dorskind's book. Its a waste of money. Never purchasing this product again.
#
# ----
#
#
#
#
# Robustness
#
# punctuation
# Test cases:      500
# Fails (rate):    7 (1.4%)
#
# Example fails:
# 0.1 0.0 0.9 great product...for the time it lasts I received an ipod nano 4gb as a gift. It was great other than it got WAY scratched up in about a day of usage. After having it & using it for about 3 weeks, I had it in my pants pocket, when i took my pants off that evening it destroyed the screen. It still worked but the screen was completely damaged. It worked for a good 2 or so months later & then when completely dead. It would be one thing if all these problems came with a cheaper price, but $250 is an insane price to pay for something that will not be sturdy whatsoever & couple possibly give you less than 2 months of usage. I strongly recommend you pass this up & purchase a product that is actually reliable.
# 0.0 0.8 0.2 great product...for the time it lasts I received an ipod nano 4gb as a gift. It was great other than it got WAY scratched up in about a day of usage. After having it & using it for about 3 weeks, I had it in my pants pocket, when i took my pants off that evening it destroyed the screen. It still worked but the screen was completely damaged. It worked for a good 2 or so months later & then when completely dead. It would be one thing if all these problems came with a cheaper price, but $250 is an insane price to pay for something that will not be sturdy whatsoever & couple possibly give you less than 2 months of usage. I strongly recommend you pass this up & purchase a product that is actually reliable
#
# ----
# 0.1 0.9 0.0 a priceless collection of songs from a unheralded band I've recently ordered O&O by The Zombies on CD, having been quite close friends with the vinyl version I purchased in the late sixties. I almost wore the grooves out of that record and hadn't discovered its availability on CD until recently. It's like finding a lost friend. It's hard to believe the musical careers of The Zombies was so short-lived.
# 0.1 0.0 0.9 a priceless collection of songs from a unheralded band I've recently ordered O&O by The Zombies on CD, having been quite close friends with the vinyl version I purchased in the late sixties. I almost wore the grooves out of that record and hadn't discovered its availability on CD until recently. It's like finding a lost friend. It's hard to believe the musical careers of The Zombies was so short-lived
#
# ----
# 0.2 0.0 0.8 This is great but the sound is kinda bad. I love Slayers!!! The story is great, the fighting is great, but i have one problem and that's the sound. For example their's a guy walking down a hall right while the foot steps sounds get their before the guy's feet touch the ground!!!! That's a bad thing people!!! And another thing is when Lina is talking her mouth this moving and she isn't talking!!!! But other than a few sound problems this's a fun box set.
# 0.7 0.0 0.3 This is great but the sound is kinda bad. I love Slayers!!! The story is great, the fighting is great, but i have one problem and that's the sound. For example their's a guy walking down a hall right while the foot steps sounds get their before the guy's feet touch the ground!!!! That's a bad thing people!!! And another thing is when Lina is talking her mouth this moving and she isn't talking!!!! But other than a few sound problems this's a fun box set
#
# ----
#
#
# typos
# Test cases:      500
# Fails (rate):    10 (2.0%)
#
# Example fails:
# 0.4 0.6 0.0 Can't Keep That Girl Down September and October seems to have given us a bumper crop of albums by 'mature' artists and here's another by a truly great singer. This time out, it's a more commercial venture than her jazz oriented tunes. Listen to the 'cover' tunes which Natalie at once makes her own. 'Old Man' 'Criminal' etc. are great songs but the cream of the crop has to be the title song. The question now is, why wasn't this album advertised more as least in this part of the world. Keyboards seem to more prevalent in the new offerings and this one is no exception. If you're a Natalie fan, you'll love it. If you're not, why not give it a try.
# 0.7 0.0 0.3 Can't Keep That Girl Down September and October seems to have given us a bumper crop of albmus by 'mature' artists and here's another by a truly great singer. This time out, it's a more commercial venture than her jazz oriented tunes. Listen to the 'cover' tunes which Natalie at once makes her own. 'Old Man' 'Criminal' etc. are great songs but the cream of the crop has to be the title song. The question now is, why wasn't this album advertised more as least in this part of the world. Keyboards seem to more prevalent in the new offerings and this one is no exception. If you're a Natalie fan, you'll love it. If you're not, why not give it a try.
#
# ----
# 0.8 0.0 0.2 Dad is in Trouble This movie is about two twins who look alike and they are on there own soccer team.They switch teams without their mom nowing.
# 0.1 0.0 0.9 Dad is in Troubl eThis movie is about two twins who look alike and they are on there own soccer team.They switch teams without their mom nowing.
#
# ----
# 0.2 0.0 0.8 Fine performances, but... Watchable for the performances, but wildly overrated, as is nearly every Polanski film. "LA Confidential" probably could not exist if "Chinatown" hadn't, but the truth is "Confidentail" is everything this film isn't. Now if we could have just time-morphed Nicholson and Dunaway into "Confidential..."
# 0.7 0.0 0.3 Fine eprformances, but... Watchable for the performances, but wildly overrated, as is nearly every Polanski film. "LA Confidential" probably could not exist if "Chinatown" hadn't, but the truth is "Confidentail" is everything this film isn't. Now if we could have just time-morphed Nicholson and Dunaway into "Confidential..."
#
# ----
#
#
# 2 typos
# Test cases:      500
# Fails (rate):    28 (5.6%)
#
# Example fails:
# 0.1 0.0 0.9 the best i sometimes think of that final list of the finest movies i've ever seen. after much soul searching and viewing films for over 50 years, i narrowed it down to amadeus, private ryan, manchurian candidate (frank sinatra), high noon and no country. after everything shakes out, THE INSIDER would have to top the list. acting, directing, music, script and subject matter. i just wish it was on blu ray.
# 0.0 0.5 0.5 the best i sometimes think of that final list of the finest movies i've ever seen. after much soul searching andv iewing films for over 50 years, i narrwoed it down to amadeus, private ryan, manchurian candidate (frank sinatra), high noon and no country. after everything shakes out, THE INSIDER would have to top the list. acting, directing, music, script and subject matter. i just wish it was on blu ray.
#
# ----
# 0.1 0.9 0.0 ellery queen mysteriesa This was a very different type of book from what i'm usesd to. It was very goog.I am a big fan of ellery queen.
# 1.0 0.0 0.0 ellery queen mysteiresa This was a very difefrent type of book from what i'm usesd to. It was very goog.I am a big fan of ellery queen.
#
# ----
# 0.0 0.7 0.3 Works for 6 weeks This unit broke, simply stopped working after six weeks since opening the box. The unit was used nearly every day 5 days a week in an industrial, workbench environment. I believe the units works well when functional. Perhaps it is most suited for hobbyists.Edit: Amazon replaced our unit with a duplicate model without labels or brand stickers. It still works today.
# 0.2 0.0 0.8 Works for 6 weeks This unit broke, simply stopped working after six weeks since opening the box. The unit was used nearly every day 5 days a week in an industrial, workbenche nvironment. I believe the units works well when functional. Perhaps it is most suited for hobbyists.Edit: Aamzon replaced our unit with a duplicate model without labels or brand stickers. It still works today.
#
# ----
#
#
# contractions
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    14 (2.8%)
#
# Example fails:
# 0.2 0.0 0.8 Power Through Constructive thinking Emmet Fox's books are so classic. He is a prolific writer with mystic abilities. I like the simjplicity with which he explains the most of complex mysteries of our universe and creation. His explanations of the writings of Jesus, be it the Lord's Prayer, or the Sermon on the Mount, etc. are profound. That's it...why ruin his incredible insights with my limited vocabulary!
# 0.0 0.7 0.3 Power Through Constructive thinking Emmet Fox's books are so classic. He's a prolific writer with mystic abilities. I like the simjplicity with which he explains the most of complex mysteries of our universe and creation. His explanations of the writings of Jesus, be it the Lord's Prayer, or the Sermon on the Mount, etc. are profound. That's it...why ruin his incredible insights with my limited vocabulary!
#
# ----
# 0.3 0.0 0.7 fitful I think most of this movie is mediocre at best. It's contrived, formulaic, poorly written and acted. But, the half-hour of slapstick when the burglars are trying to break into the home is SO hilarious, it's worth sitting through the other parts. It's really a hilarious half hour. So, that's a mixed review!
# 0.0 0.7 0.3 fitful I think most of this movie is mediocre at best. It is contrived, formulaic, poorly written and acted. But, the half-hour of slapstick when the burglars are trying to break into the home is SO hilarious, it is worth sitting through the other parts. It is really a hilarious half hour. So, that is a mixed review!
#
# ----
# 0.1 0.0 0.9 What are you listening to? That music is Garbage! All hail Shirley Manson! This CD is awsome. Not many of the songs are fast, but you can't help but love every track. Every time I put it on to listen to one song, I can't help but listen to all of them. Each one is unique. All of my friends are sick and tired of listening to it because when I put in a CD, chances are that its going to be Garbage.
# 0.0 1.0 0.0 What are you listening to? That music is Garbage! All hail Shirley Manson! This CD is awsome. Not many of the songs are fast, but you cannot help but love every track. Every time I put it on to listen to one song, I cannot help but listen to all of them. Each one is unique. All of my friends are sick and tired of listening to it because when I put in a CD, chances are that its going to be Garbage.
#
# ----
#
#
#
#
# Fairness
#
# protected: race
# Test cases:      600
# Test cases run:  500
# Fails (rate):    292 (58.4%)
#
# Example fails:
# 0.2 0.8 0.0 Angela is a black lawyer.
# 0.0 0.0 1.0 Angela is a hispanic lawyer.
# 0.2 0.0 0.8 Angela is a white lawyer.
#
# ----
# 0.4 0.6 0.0 Jean is a black female.
# 0.0 0.0 1.0 Jean is a hispanic female.
# 0.2 0.0 0.8 Jean is a white female.
#
# ----
# 0.9 0.0 0.1 Karen is a black color.
# 0.0 0.0 1.0 Karen is an asian color.
# 0.0 0.0 1.0 Karen is a hispanic color.
#
# ----
#
#
# protected: sexual
# Test cases:      600
# Test cases run:  500
# Fails (rate):    446 (89.2%)
#
# Example fails:
# 0.0 0.0 1.0 Frances is an asexual performer.
# 0.2 0.8 0.0 Frances is a queer performer.
# 0.4 0.6 0.0 Frances is a cisgender performer.
#
# ----
# 0.0 0.0 1.0 Dave is an asexual person.
# 0.4 0.6 0.0 Dave is a trans person.
# 1.0 0.0 0.0 Dave is a bisexual person.
#
# ----
# 0.0 0.0 1.0 Alexander is an asexual son.
# 0.9 0.0 0.1 Alexander is a queer son.
# 0.9 0.0 0.1 Alexander is a homosexual son.
#
# ----
#
#
# protected: religion
# Test cases:      600
# Test cases run:  500
# Fails (rate):    472 (94.4%)
#
# Example fails:
# 0.0 0.0 1.0 Ellen is a Christian activist.
# 0.9 0.0 0.1 Ellen is an Atheist activist.
# 0.0 0.5 0.5 Ellen is a Sunni activist.
#
# ----
# 0.0 0.0 1.0 Andrew is a Christian Zionist.
# 0.9 0.0 0.1 Andrew is an Atheist Zionist.
#
# ----
# 0.0 0.0 1.0 Anne is a Christian priest.
# 1.0 0.0 0.0 Anne is an Atheist priest.
# 0.0 0.8 0.2 Anne is a Shinto priest.
#
# ----
#
#
# protected: nationality
# Test cases:      600
# Test cases run:  500
# Fails (rate):    39 (7.8%)
#
# Example fails:
# 0.0 0.0 1.0 Emily is a Chinese Mormon.
# 0.3 0.7 0.0 Emily is a German Mormon.
# 0.7 0.0 0.3 Emily is a Bangladeshi Mormon.
#
# ----
# 0.2 0.0 0.8 Sandra is a Chinese feminist.
# 0.1 0.9 0.0 Sandra is a Pakistani feminist.
# 0.3 0.7 0.0 Sandra is a German feminist.
#
# ----
# 0.1 0.0 0.9 Eleanor is a Chinese transplant.
# 0.2 0.8 0.0 Eleanor is a Turkish transplant.
# 0.0 0.8 0.2 Eleanor is a Vietnamese transplant.
#
# ----
#
#
# protected: country
# Test cases:      600
# Test cases run:  500
# Fails (rate):    376 (75.2%)
#
# Example fails:
# 0.0 0.0 1.0 Paul is a China banker.
# 0.5 0.5 0.0 Paul is a Turkey banker.
# 0.9 0.0 0.1 Paul is a Vietnam banker.
#
# ----
# 0.0 0.0 1.0 Sam is a China student.
# 0.3 0.7 0.0 Sam is a Panama student.
# 0.2 0.8 0.0 Sam is a Nicaragua student.
#
# ----
# 0.0 0.0 1.0 Louise is a China senator.
# 0.0 1.0 0.0 Louise is a Mali senator.
# 0.0 1.0 0.0 Louise is an Iraq senator.
#
# ----
#
#
#
#
# Temporal
#
# used to, but now
# Test cases:      8000
# Test cases run:  500
# Fails (rate):    159 (31.8%)
#
# Example fails:
# 0.0 0.0 1.0 I used to value this movie, although now I abhor it.
# ----
# 0.9 0.0 0.1 In the past I would despise this movie, even though now I admired it.
# ----
# 0.0 0.0 1.0 In the past I thought this movie was wonderful, even though now I think it is rough.
# ----
#
#
# "used to" should reduce
# Test cases:      14616
# Test cases run:  500
# After filtering: 11 (2.2%)
# Fails (rate):    7 (63.6%)
#
# Example fails:
# 0.9 0.0 0.1 that was a difficult adventure movie.
# 1.0 0.0 0.0 I used to think that was a difficult adventure movie.
#
# ----
# 0.8 0.0 0.2 this is a terrible mystery.
# 0.9 0.0 0.1 I used to think this is a terrible mystery.
#
# ----
# 0.8 0.0 0.2 this was a creepy animation.
# 1.0 0.0 0.0 I used to think this was a creepy animation.
#
# ----
#
#
#
#
# Negation
#
# simple negations: negative
# Test cases:      21924
# Test cases run:  500
# Fails (rate):    32 (6.4%)
#
# Example fails:
# 0.0 0.0 1.0 I would never say I like that smartwatch.
# ----
# 0.0 0.0 1.0 I can't say I admire this documentary.
# ----
# 0.0 0.0 1.0 I would never say I value this adventure movie.
# ----
#
#
# simple negations: not negative
# Test cases:      21924
# Test cases run:  500
# Fails (rate):    75 (15.0%)
#
# Example fails:
# 1.0 0.0 0.0 The coming of age movie is not creepy.
# ----
# 1.0 0.0 0.0 I can't say I abhor that horror movie.
# ----
# 0.9 0.0 0.1 No one dislikes the fantasy.
# ----
#
#
# simple negations: not neutral is still neutral
# Test cases:      8064
# Test cases run:  500
# Fails (rate):    492 (98.4%)
#
# Example fails:
# 0.9 0.0 0.1 It was not an Italian adventure movie.
# ----
# 1.0 0.0 0.0 It wasn't an Indian CD.
# ----
# 1.0 0.0 0.0 This is not a commercial family.
# ----
#
#
# simple negations: I thought x was positive, but it was not (should be negative)
# Test cases:      7182
# Test cases run:  500
# Fails (rate):    0 (0.0%)
#
#
# simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Test cases:      7170
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought this romance would be frustrating, but it wasn't.
# ----
# 1.0 0.0 0.0 I thought I would dislike the book, but I didn't.
# ----
# 1.0 0.0 0.0 I thought this comedy would be creepy, but it wasn't.
# ----
#
#
# simple negations: but it was not (neutral) should still be neutral
# Test cases:      2718
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought this series would be Australian, but it wasn't.
# ----
# 1.0 0.0 0.0 I thought that documentary would be Indian, but it was not.
# ----
# 1.0 0.0 0.0 I thought that short film would be international, but it wasn't.
# ----
#
#
# Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    475 (95.0%)
#
# Example fails:
# 0.0 0.0 1.0 I don't think, given Its better then a normal bed, that the remale is awesome.
# ----
# 0.0 0.0 1.0 I wouldn't say, given  Its been 2 months since I moved out, that this horror movie was happy.
# ----
# 0.0 0.0 1.0 I don't think, given I just moved out of my moms house, that the was an awesome western movie.
# ----
#
#
# Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    496 (99.2%)
#
# Example fails:
# 1.0 0.0 0.0 I can't say, given I just moved out of my moms house, that the fantasy is weird.
# ----
# 1.0 0.0 0.0 i wouldn't say, given  its like sleeping on a cloud., that we abhor this romance.
# ----
# 1.0 0.0 0.0 i don't think, given I just moved out of my moms house, that this was a hard gift.
# ----
#
#
# negation of neutral with neutral in the middle, should still neutral
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    485 (97.0%)
#
# Example fails:
# 1.0 0.0 0.0 I can't say, given  Its been 2 months since I moved out, that this is a private E-book.
# ----
# 1.0 0.0 0.0 I wouldn't say, given I just moved out of my moms house, that that is an Italian track.
# ----
# 1.0 0.0 0.0 I don't think, given  its like sleeping on a cloud., that the is a private comedy.
# ----
#
#
#
#
# SRL
#
# my opinion is what matters
# Test cases:      9264
# Test cases run:  500
# Fails (rate):    211 (42.2%)
#
# Example fails:
# 1.0 0.0 0.0 I think product are exceptional, I had heard product were awful.
# ----
# 1.0 0.0 0.0 I think product are amazing, some people think product are dreadful.
# ----
# 0.8 0.0 0.2 I think product are happy, some people think product are average.
# ----
#
#
# Q & A: yes
# Test cases:      25704
# Test cases run:  500
# Fails (rate):    17 (3.4%)
#
# Example fails:
# 0.0 0.7 0.3 Did we value this smartwatch? Yes
# ----
# 1.0 0.0 0.0 Do I think that was a nice laptop? Yes
# ----
# 0.3 0.7 0.0 Do I think it is a nice war? Yes
# ----
#
#
# Q & A: yes (neutral)
# Test cases:      5040
# Test cases run:  500
# Fails (rate):    476 (95.2%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think that was a commercial animation? Yes
# ----
# 1.0 0.0 0.0 Do I think this headphone is private? Yes
# ----
# 1.0 0.0 0.0 Do I think the mystery was Australian? Yes
# ----
#
#
# Q & A: no
# Test cases:      25704
# Test cases run:  500
# Fails (rate):    426 (85.2%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think this was a dreadful short film? No
# ----
# 1.0 0.0 0.0 Do I think that book is rough? No
# ----
# 0.0 0.0 1.0 Do I think this is a well silent movie? No
# ----
#
#
# Q & A: no (neutral)
# Test cases:      5040
# Test cases run:  500
# Fails (rate):    499 (99.8%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think it was a British book? No
# ----
# 1.0 0.0 0.0 Do I think that was an international short film? No
# ----
# 0.9 0.0 0.1 Do I think the gift is international? No
# ----
