# %% [markdown]
# # Test sentimental
# This notebook is used to test the sentiment analysis model. It involves loading the pretrained model (distilbert/distilbert-base-uncased-finetuned-sst-2-english from huggingface), running it on the test dataset, and evaluating its performance.

# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
import numpy as np
import spacy
from checklist.test_suite import TestSuite
from checklist.perturb import Perturb
from transformers import pipeline

# %%
# use pipeline sentimental analysis
# model = pipeline("sentiment-analysis")
# revision = "af0f99b"

# Specify the model name 
model_name = "distilbert/distilbert-base-uncased-finetuned-sst-2-english"

# Initialize the pipeline with the specified model and revision
nlp_pipeline = pipeline("sentiment-analysis", model=model_name)

# %%
# decrease size of chunk
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# use to process the data with the sentimental model
def batch_predict(model, data, batch_size=128):
    ret = []
    for d in chunks(data, batch_size):
        ret.extend(model(d))
    return ret

# %%
import numpy as np

# Function to check the score
# I am not sure about the score that author has calculated.
def pred_and_conf(data):
    # change format to softmax, make everything in [0.33, 0.66] range be predicted as neutral
    preds = batch_predict(model, data)
    pr = np.array([x['score'] if x['label'] == 'POSITIVE' else 1 - x['score'] for x in preds])
    pp = np.zeros((pr.shape[0], 3))
    margin_neutral = 1/3.
    mn = margin_neutral / 2.
    neg = pr < 0.5 - mn
    pp[neg, 0] = 1 - pr[neg]
    pp[neg, 2] = pr[neg]
    pos = pr > 0.5 + mn
    pp[pos, 0] = 1 - pr[pos]
    pp[pos, 2] = pr[pos]
    neutral_pos = (pr >= 0.5) * (pr < 0.5 + mn)
    pp[neutral_pos, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_pos] - 0.5)
    pp[neutral_pos, 2] = 1 - pp[neutral_pos, 1]
    neutral_neg = (pr < 0.5) * (pr > 0.5 - mn)
    pp[neutral_neg, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_neg] - 0.5)
    pp[neutral_neg, 0] = 1 - pp[neutral_neg, 1]
    preds = np.argmax(pp, axis=1)
    return preds, pp

# %%
suite_path = 'sentiment_suite.pkl' #define suite path name
suite = TestSuite.from_file(suite_path)

# %%
# run the test suite with 500 samples and check score with `pred_and_conf` function
suite.run(pred_and_conf, n=500)
# Out:
# Running single positive words
# Predicting 34 examples
# Running single negative words
# Predicting 35 examples
# Running single neutral words
# Predicting 13 examples
# Running Sentiment-laden words in context
# Predicting 500 examples
# Running neutral words in context
# Predicting 500 examples
# Running intensifiers
# Predicting 1000 examples
# Running reducers
# Predicting 1000 examples
# Running change neutral words with BERT
# Predicting 5092 examples
# Running add positive phrases
# Predicting 5500 examples
# Running add negative phrases
# Predicting 5500 examples
# Running add random urls and handles
# Predicting 11000 examples
# Running punctuation
# Predicting 1154 examples
# Running typos
# Predicting 1000 examples
# Running 2 typos
# Predicting 1000 examples
# Running contractions
# Predicting 1034 examples
# Running change names
# Predicting 3311 examples
# Running change locations
# Predicting 5500 examples
# Running used to, but now
# Predicting 500 examples
# Running "used to" should reduce
# Predicting 1000 examples
# Running protected: race
# Predicting 2000 examples
# Running protected: sexual
# Predicting 7000 examples
# Running protected: religion
# Predicting 11000 examples
# Running protected: nationality
# Predicting 10000 examples
# Running simple negations: negative
# Predicting 500 examples
# Running simple negations: not negative
# Predicting 500 examples
# Running simple negations: not neutral is still neutral
# Predicting 500 examples
# Running simple negations: I thought x was positive, but it was not (should be negative)
# Predicting 500 examples
# Running simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Predicting 500 examples
# Running simple negations: but it was not (neutral) should still be neutral
# Predicting 500 examples
# Running Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Predicting 500 examples
# Running Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Predicting 500 examples
# Running negation of neutral with neutral in the middle, should still neutral
# Predicting 500 examples
# Running my opinion is what matters
# Predicting 500 examples
# Running Q & A: yes
# Predicting 500 examples
# Running Q & A: yes (neutral)
# Predicting 500 examples
# Running Q & A: no
# Predicting 500 examples
# Running Q & A: no (neutral)
# Predicting 500 examples

# %%
suite.summary() #summary the test case
# Out:
# Vocabulary
#
# single positive words
# Test cases:      34
# Fails (rate):    0 (0.0%)
#
#
# single negative words
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.3 0.0 0.7 average
# ----
#
#
# single neutral words
# Test cases:      13
# Fails (rate):    13 (100.0%)
#
# Example fails:
# 0.0 0.0 1.0 British
# ----
# 0.0 0.0 1.0 international
# ----
# 0.0 0.0 1.0 Italian
# ----
#
#
# Sentiment-laden words in context
# Test cases:      8658
# Test cases run:  500
# Fails (rate):    7 (1.4%)
#
# Example fails:
# 0.0 0.0 1.0 This was an average flight.
# ----
# 0.0 0.0 1.0 This is an average customer service.
# ----
# 0.3 0.0 0.7 That was an average service.
# ----
#
#
# neutral words in context
# Test cases:      1716
# Test cases run:  500
# Fails (rate):    478 (95.6%)
#
# Example fails:
# 0.0 0.0 1.0 This aircraft is British.
# ----
# 1.0 0.0 0.0 The customer service was commercial.
# ----
# 0.0 0.0 1.0 That was an Israeli food.
# ----
#
#
# intensifiers
# Test cases:      2000
# Test cases run:  500
# After filtering: 499 (99.8%)
# Fails (rate):    7 (1.4%)
#
# Example fails:
# 0.0 0.0 1.0 This was a creepy pilot.
# 0.7 0.0 0.3 This was an utterly creepy pilot.
#
# ----
# 0.2 0.0 0.8 It is an average airline.
# 1.0 0.0 0.0 It is an incredibly average airline.
#
# ----
# 0.2 0.0 0.8 This was a creepy flight.
# 0.3 0.7 0.0 This was a very creepy flight.
#
# ----
#
#
# reducers
# Test cases:      2000
# Test cases run:  500
# After filtering: 2 (0.4%)
# Fails (rate):    0 (0.0%)
#
#
# change neutral words with BERT
# Test cases:      500
# Fails (rate):    61 (12.2%)
#
# Example fails:
# 0.0 0.8 0.2 @JetBlue can you DM?
# 1.0 0.0 0.0 @JetBlue can it DM?
# 1.0 0.0 0.0 @JetBlue can I DM?
#
# ----
# 0.1 0.0 0.9 @JetBlue It drops 75 when i take off the other two people, and vice versa. back and forth.
# 1.0 0.0 0.0 @JetBlue It drops 75 when i take off the other two people, not vice versa. back not forth.
# 1.0 0.0 0.0 @JetBlue It drops 75 when i take off the other two people, not vice versa. back not forth.
#
# ----
# 0.0 0.0 1.0 @JetBlue Call me when you do and we’ll have to hook up!
# 0.7 0.0 0.3 @JetBlue Call me when you do – we’ll have to hook up!
#
# ----
#
#
# add positive phrases
# Test cases:      500
# Fails (rate):    0 (0.0%)
#
#
# add negative phrases
# Test cases:      500
# Fails (rate):    28 (5.6%)
#
# Example fails:
# 0.9 0.0 0.1 @AmericanAir Yes, thanks I found those, didn't see the gray tab at first :)
# 0.8 0.0 0.2 @AmericanAir Yes, thanks I found those, didn't see the gray tab at first. Never flying with you again.
#
# ----
# 1.0 0.0 0.0 @united should hire extra customer service reps. 50 minute wait time to ask one question? I would rather just fly another airline, thanks.
# 0.8 0.0 0.2 @united should hire extra customer service reps. 50 minute wait time to ask one question? I would rather just fly another airline, thanks. You are average.
#
# ----
# 0.9 0.0 0.1 @USAirways now on hold for 90 minutes
# 0.0 0.0 1.0 @USAirways now on hold for 90 minutes. You are average.
#
# ----
#
#
#
#
# Robustness
#
# add random urls and handles
# Test cases:      500
# Fails (rate):    71 (14.2%)
#
# Example fails:
# 0.0 0.0 1.0 @AmericanAir  thanks hoping that by wed I can get back to DFW
# 1.0 0.0 0.0 @AmericanAir  thanks hoping that by wed I can get back to DFW https://t.co/HZlwkF
# 0.9 0.0 0.1 @AmericanAir  thanks hoping that by wed I can get back to DFW https://t.co/7rnP7j
#
# ----
# 0.0 0.0 1.0 @USAirways i have been patient.. especially the first time. i will never fly with you again
# 0.3 0.7 0.0 https://t.co/DG8pf0 @USAirways i have been patient.. especially the first time. i will never fly with you again
# 0.9 0.0 0.1 https://t.co/fNOSyB @USAirways i have been patient.. especially the first time. i will never fly with you again
#
# ----
# 0.8 0.0 0.2 @USAirways I'm glad too. But I should not have to spend an hour to try and track down the basic information that you already have available.
# 0.5 0.5 0.0 @BJ3Jww @USAirways I'm glad too. But I should not have to spend an hour to try and track down the basic information that you already have available.
#
# ----
#
#
# punctuation
# Test cases:      500
# Fails (rate):    20 (4.0%)
#
# Example fails:
# 0.3 0.0 0.7 @SouthwestAir Learn how to give folks on multiple flights the same day boarding position at least if you can't give them  boarding passes.
# 0.0 0.6 0.4 @SouthwestAir Learn how to give folks on multiple flights the same day boarding position at least if you can't give them  boarding passes
#
# ----
# 1.0 0.0 0.0 @SouthwestAir @CallMeStanley7 And bring back the "Agent will call you back..." feature. Why was that ever discontinued???
# 0.2 0.8 0.0 @SouthwestAir @CallMeStanley7 And bring back the "Agent will call you back..." feature. Why was that ever discontinued
#
# ----
# 0.8 0.0 0.2 @USAirways what is the baggage allowance on flights from Glasgow to the US?  Thanks
# 0.3 0.0 0.7 @USAirways what is the baggage allowance on flights from Glasgow to the US?  Thanks.
#
# ----
#
#
# typos
# Test cases:      500
# Fails (rate):    35 (7.0%)
#
# Example fails:
# 0.2 0.0 0.8 @united splitting up my flights quadruples the price
# 0.1 0.9 0.0 @united splitting u pmy flights quadruples the price
#
# ----
# 0.2 0.8 0.0 @AmericanAir All flts to JFK Cancelled Flightled Thx to UR agent at SFO Im rebooked on UA. Didn't get name. She was awesome!  #twitterhug #shesaidrun
# 0.8 0.0 0.2 @AmericanAir All flts to JFK Cancelled Flightled Thx to UR agent at SFO Im rebooked on UA. Ddin't get name. She was awesome!  #twitterhug #shesaidrun
#
# ----
# 0.0 0.0 1.0 @united it's done.  If you do something to make up for it I'll tweet that too.
# 0.4 0.6 0.0 @united it's odne.  If you do something to make up for it I'll tweet that too.
#
# ----
#
#
# 2 typos
# Test cases:      500
# Fails (rate):    50 (10.0%)
#
# Example fails:
# 0.2 0.0 0.8 @AmericanAir ok makes no sense tho Since you'll give me a free upgrade to first.
# 1.0 0.0 0.0 @AmericanAir ok makes no sens etho Since you'll giv eme a free upgrade to first.
#
# ----
# 0.0 0.0 1.0 @SouthwestAir Thanks for getting us to paradise safely! http://t.co/KDzQcZlpyR
# 1.0 0.0 0.0 @SouthwestAir Thansk for getting us to paradise safely! http://t.co/KDzQclZpyR
#
# ----
# 0.0 0.0 1.0 @VirginAmerica when are you flying to hawaii
# 0.0 0.8 0.2 @VirginAmerica when are oyu flying to hwaaii
#
# ----
#
#
# contractions
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    21 (4.2%)
#
# Example fails:
# 0.2 0.8 0.0 @united Okay thanks if you could please update me. I was told at the airport someone would call me today but they haven't.
# 0.7 0.0 0.3 @united Okay thanks if you could please update me. I was told at the airport someone would call me today but they have not.
#
# ----
# 0.2 0.0 0.8 @united @staralliance Very nice at LHR, congrats, but I'm sticking with AA/#BA. @AmericanAir @British_Airways
# 0.7 0.0 0.3 @united @staralliance Very nice at LHR, congrats, but I am sticking with AA/#BA. @AmericanAir @British_Airways
#
# ----
# 0.0 0.5 0.5 @americanair I sure do. I'm running version 3.10.0
# 0.2 0.0 0.8 @americanair I sure do. I am running version 3.10.0
#
# ----
#
#
#
#
# NER
#
# change names
# Test cases:      301
# Fails (rate):    13 (4.3%)
#
# Example fails:
# 0.3 0.7 0.0 @united yes, David Allan send an email with this number (KMM24999563V99860L0KM) and case#8719519
# 0.7 0.0 0.3 @united yes, David Morgan send an email with this number (KMM24999563V99860L0KM) and case#8719519
# 0.8 0.0 0.2 @united yes, John Edwards send an email with this number (KMM24999563V99860L0KM) and case#8719519
#
# ----
# 0.7 0.0 0.3 @JetBlue to start 3xweekly @EmbraerSA #E190 flights from #Washington Reagan to #Nantucket between 19JUN-6SEP #avgeek
# 0.1 0.9 0.0 @JetBlue to start 3xweekly @EmbraerSA #E190 flights from #Michael Carter to #Nantucket between 19JUN-6SEP #avgeek
# 0.3 0.7 0.0 @JetBlue to start 3xweekly @EmbraerSA #E190 flights from #Christopher Evans to #Nantucket between 19JUN-6SEP #avgeek
#
# ----
# 0.7 0.0 0.3 @SouthwestAir still haven't left @BWI. Maybe by the time I'm suppose to fly back to Austin on Tuesday we'll have moved.
# 0.5 0.5 0.0 @SouthwestAir still haven't left @BWI. Maybe by the time I'm suppose to fly back to Christian on Tuesday we'll have moved.
# 0.5 0.5 0.0 @SouthwestAir still haven't left @BWI. Maybe by the time I'm suppose to fly back to Jonathan on Tuesday we'll have moved.
#
# ----
#
#
# change locations
# Test cases:      928
# Test cases run:  500
# Fails (rate):    35 (7.0%)
#
# Example fails:
# 0.1 0.0 0.9 @united can you ask your guys with flight 1146 to BWI to wait for us to get off a delayed flight from San Diego? Pretty please?
# 0.2 0.8 0.0 @united can you ask your guys with flight 1146 to BWI to wait for us to get off a delayed flight from Lexington-Fayette? Pretty please?
# 0.2 0.8 0.0 @united can you ask your guys with flight 1146 to BWI to wait for us to get off a delayed flight from Portland? Pretty please?
#
# ----
# 0.3 0.0 0.7 @JetBlue Flight 136 departed Phoenix at 1:30 am
# 0.0 0.9 0.1 @JetBlue Flight 136 departed Toledo at 1:30 am
# 0.0 0.7 0.3 @JetBlue Flight 136 departed Memphis at 1:30 am
#
# ----
# 0.8 0.0 0.2 @USAirways seriously buy some WD40 for A319 operating flight 634 from GEG to Phoenix. Every seat squeaks w every shift. Still on ground!
# 0.0 0.9 0.1 @USAirways seriously buy some WD40 for A319 operating flight 634 from GEG to Kansas City. Every seat squeaks w every shift. Still on ground!
#
# ----
#
#
#
#
# Fairness
#
# protected: race
# Test cases:      600
# Test cases run:  500
# Fails (rate):    287 (57.4%)
#
# Example fails:
# 0.9 0.0 0.1 Kelly is a black lesbian.
# 0.0 0.9 0.1 Kelly is an asian lesbian.
#
# ----
# 0.9 0.0 0.1 Jack is a black author.
# 0.0 0.0 1.0 Jack is an asian author.
# 0.0 0.0 1.0 Jack is a hispanic author.
#
# ----
# 0.9 0.0 0.1 Karen is a black color.
# 0.0 0.0 1.0 Karen is an asian color.
# 0.0 0.0 1.0 Karen is a hispanic color.
#
# ----
#
#
# protected: sexual
# Test cases:      600
# Test cases run:  500
# Fails (rate):    443 (88.6%)
#
# Example fails:
# 0.0 0.0 1.0 Katie is an asexual myself.
# 1.0 0.0 0.0 Katie is a gay myself.
# 1.0 0.0 0.0 Katie is a lesbian myself.
#
# ----
# 0.0 0.0 1.0 Jill is an asexual philosopher.
# 0.4 0.6 0.0 Jill is a lesbian philosopher.
# 0.9 0.0 0.1 Jill is a gay philosopher.
#
# ----
# 0.0 0.0 1.0 Dan is an asexual brother.
# 1.0 0.0 0.0 Dan is a gay brother.
# 0.9 0.0 0.1 Dan is a homosexual brother.
#
# ----
#
#
# protected: religion
# Test cases:      600
# Test cases run:  500
# Fails (rate):    480 (96.0%)
#
# Example fails:
# 0.0 0.0 1.0 Daniel is a Christian male.
# 1.0 0.0 0.0 Daniel is an Atheist male.
# 0.8 0.0 0.2 Daniel is an Agnostic male.
#
# ----
# 0.2 0.0 0.8 Jason is a Christian supremacist.
# 0.0 1.0 0.0 Jason is an Ahmadiyya supremacist.
# 0.2 0.8 0.0 Jason is a Confucian supremacist.
#
# ----
# 0.0 0.0 1.0 Michelle is a Christian Democrat.
# 1.0 0.0 0.0 Michelle is an Atheist Democrat.
# 0.9 0.0 0.1 Michelle is a Shinto Democrat.
#
# ----
#
#
# protected: nationality
# Test cases:      600
# Test cases run:  500
# Fails (rate):    33 (6.6%)
#
# Example fails:
# 0.3 0.0 0.7 Victoria is a Chinese dentist.
# 0.0 0.9 0.1 Victoria is a Bangladeshi dentist.
# 0.0 0.8 0.2 Victoria is a Pakistani dentist.
#
# ----
# 0.1 0.0 0.9 Emily is a Chinese activist.
# 0.7 0.0 0.3 Emily is a German activist.
#
# ----
# 0.2 0.0 0.8 Henry is a Chinese migrant.
# 0.5 0.5 0.0 Henry is a Japanese migrant.
# 0.8 0.0 0.2 Henry is a German migrant.
#
# ----
#
#
#
#
# Temporal
#
# used to, but now
# Test cases:      8000
# Test cases run:  500
# Fails (rate):    154 (30.8%)
#
# Example fails:
# 0.1 0.0 0.9 I think this airline is weird,  I used to think it was exceptional.
# ----
# 0.0 0.0 1.0 In the past I would love this airline, although now I dread it.
# ----
# 0.0 0.0 1.0 I abhor this airline, even though in the past I would appreciate it.
# ----
#
#
# "used to" should reduce
# Test cases:      4368
# Test cases run:  500
# After filtering: 5 (1.0%)
# Fails (rate):    0 (0.0%)
#
#
#
#
# Negation
#
# simple negations: negative
# Test cases:      6318
# Test cases run:  500
# Fails (rate):    32 (6.4%)
#
# Example fails:
# 0.0 0.0 1.0 I would never say I admire the food.
# ----
# 0.0 0.5 0.5 I can't say I enjoy this airline.
# ----
# 0.0 0.0 1.0 I would never say I enjoy the service.
# ----
#
#
# simple negations: not negative
# Test cases:      6786
# Test cases run:  500
# Fails (rate):    60 (12.0%)
#
# Example fails:
# 1.0 0.0 0.0 I can't say I abhor this pilot.
# ----
# 1.0 0.0 0.0 It was not an average food.
# ----
# 1.0 0.0 0.0 I can't say I hate this service.
# ----
#
#
# simple negations: not neutral is still neutral
# Test cases:      2496
# Test cases run:  500
# Fails (rate):    493 (98.6%)
#
# Example fails:
# 1.0 0.0 0.0 This isn't an Israeli airline.
# ----
# 1.0 0.0 0.0 This crew is not Indian.
# ----
# 1.0 0.0 0.0 It isn't an Italian pilot.
# ----
#
#
# simple negations: I thought x was positive, but it was not (should be negative)
# Test cases:      1992
# Test cases run:  500
# Fails (rate):    0 (0.0%)
#
#
# simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Test cases:      2124
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought the staff would be ridiculous, but it was not.
# ----
# 1.0 0.0 0.0 I thought that crew would be awful, but it was not.
# ----
# 1.0 0.0 0.0 I thought I would dislike the cabin crew, but I didn't.
# ----
#
#
# simple negations: but it was not (neutral) should still be neutral
# Test cases:      804
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought I would find the crew, but I did not.
# ----
# 1.0 0.0 0.0 I thought I would see that seat, but I didn't.
# ----
# 1.0 0.0 0.0 I thought this flight would be Australian, but it wasn't.
# ----
#
#
# Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    434 (86.8%)
#
# Example fails:
# 0.0 0.0 1.0 I can't say, given all that I've seen over the years, that I enjoy this company.
# ----
# 0.0 0.0 1.0 I wouldn't say, given it's a Tuesday, that the flight is sweet.
# ----
# 0.1 0.9 0.0 I wouldn't say, given that I am from Brazil, that that service was nice.
# ----
#
#
# Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    499 (99.8%)
#
# Example fails:
# 1.0 0.0 0.0 i can't say, given the time that I've been flying, that the is a sad company.
# ----
# 1.0 0.0 0.0 i wouldn't say, given it's a Tuesday, that the is a creepy aircraft.
# ----
# 1.0 0.0 0.0 I can't say, given it's a Tuesday, that the seat is dreadful.
# ----
#
#
# negation of neutral with neutral in the middle, should still neutral
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    477 (95.4%)
#
# Example fails:
# 0.2 0.0 0.8 I can't say, given it's a Tuesday, that we find that pilot.
# ----
# 1.0 0.0 0.0 I wouldn't say, given that I am from Brazil, that the service was commercial.
# ----
# 1.0 0.0 0.0 I don't think, given the time that I've been flying, that that is an American flight.
# ----
#
#
#
#
# SRL
#
# my opinion is what matters
# Test cases:      8528
# Test cases run:  500
# Fails (rate):    221 (44.2%)
#
# Example fails:
# 1.0 0.0 0.0 I think you are great, some people think you are boring.
# ----
# 0.4 0.6 0.0 I think you are nasty, I had heard you were exceptional.
# ----
# 0.0 0.0 1.0 I think you are ridiculous, but some people think you are excellent.
# ----
#
#
# Q & A: yes
# Test cases:      7644
# Test cases run:  500
# Fails (rate):    1 (0.2%)
#
# Example fails:
# 0.0 0.8 0.2 Do I think that was a nice plane? Yes
# ----
#
#
# Q & A: yes (neutral)
# Test cases:      1560
# Test cases run:  500
# Fails (rate):    477 (95.4%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think the service was British? Yes
# ----
# 0.9 0.0 0.1 Did I find this company? Yes
# ----
# 1.0 0.0 0.0 Do I think that service is British? Yes
# ----
#
#
# Q & A: no
# Test cases:      7644
# Test cases run:  500
# Fails (rate):    426 (85.2%)
#
# Example fails:
# 0.1 0.0 0.9 Do I think this flight is exciting? No
# ----
# 1.0 0.0 0.0 Do I think the crew was ridiculous? No
# ----
# 0.0 0.0 1.0 Do I think it is a fantastic airline? No
# ----
#
#
# Q & A: no (neutral)
# Test cases:      1560
# Test cases run:  500
# Fails (rate):    499 (99.8%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think the staff is Italian? No
# ----
# 1.0 0.0 0.0 Do I think this was an Israeli flight? No
# ----
# 1.0 0.0 0.0 Do I think that was an American crew? No
# ----
