# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
import numpy as np
import spacy
from checklist.test_suite import TestSuite
from checklist.perturb import Perturb
from transformers import pipeline

# %%
# use pipeline sentimental analysis
model = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\kafka\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# used to decrease size of chunk
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# use to process the data with the sentimental model
def batch_predict(model, data, batch_size=128):
    ret = []
    for d in chunks(data, batch_size):
        ret.extend(model(d))
    return ret

# %%
import numpy as np

# Function to check the score
# I am not sure about the score that author has calculated.
def pred_and_conf(data):
    # change format to softmax, make everything in [0.33, 0.66] range be predicted as neutral
    preds = batch_predict(model, data)
    pr = np.array([x['score'] if x['label'] == 'POSITIVE' else 1 - x['score'] for x in preds])
    pp = np.zeros((pr.shape[0], 3))
    margin_neutral = 1/3.
    mn = margin_neutral / 2.
    neg = pr < 0.5 - mn
    pp[neg, 0] = 1 - pr[neg]
    pp[neg, 2] = pr[neg]
    pos = pr > 0.5 + mn
    pp[pos, 0] = 1 - pr[pos]
    pp[pos, 2] = pr[pos]
    neutral_pos = (pr >= 0.5) * (pr < 0.5 + mn)
    pp[neutral_pos, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_pos] - 0.5)
    pp[neutral_pos, 2] = 1 - pp[neutral_pos, 1]
    neutral_neg = (pr < 0.5) * (pr > 0.5 - mn)
    pp[neutral_neg, 1] = 1 - (1 / margin_neutral) * np.abs(pr[neutral_neg] - 0.5)
    pp[neutral_neg, 0] = 1 - pp[neutral_neg, 1]
    preds = np.argmax(pp, axis=1)
    return preds, pp

# %%
suite_path = 'sentiment_suite.pkl' #define suite path name
suite = TestSuite.from_file(suite_path)

# %%
suite.run(pred_and_conf, n=500) # run the test suite with 500 samples and check score with `pred_and_conf` function
# Out:
# Running single positive words
# Predicting 34 examples
# Running single negative words
# Predicting 35 examples
# Running single neutral words
# Predicting 13 examples
# Running Sentiment-laden words in context
# Predicting 500 examples
# Running neutral words in context
# Predicting 500 examples
# Running intensifiers
# Predicting 1000 examples
# Running reducers
# Predicting 1000 examples
# Running change neutral words with BERT
# Predicting 5092 examples
# Running add positive phrases
# Predicting 5500 examples
# Running add negative phrases
# Predicting 5500 examples
# Running add random urls and handles
# Predicting 11000 examples
# Running punctuation
# Predicting 1154 examples
# Running typos
# Predicting 1000 examples
# Running 2 typos
# Predicting 1000 examples
# Running contractions
# Predicting 1039 examples
# Running change names
# Predicting 3311 examples
# Running change locations
# Predicting 5500 examples
# Running used to, but now
# Predicting 500 examples
# Running "used to" should reduce
# Predicting 1000 examples
# Running protected: race
# Predicting 2000 examples
# Running protected: sexual
# Predicting 7000 examples
# Running protected: religion
# Predicting 11000 examples
# Running protected: nationality
# Predicting 10000 examples
# Running simple negations: negative
# Predicting 500 examples
# Running simple negations: not negative
# Predicting 500 examples
# Running simple negations: not neutral is still neutral
# Predicting 500 examples
# Running simple negations: I thought x was positive, but it was not (should be negative)
# Predicting 500 examples
# Running simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Predicting 500 examples
# Running simple negations: but it was not (neutral) should still be neutral
# Predicting 500 examples
# Running Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Predicting 500 examples
# Running Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Predicting 500 examples
# Running negation of neutral with neutral in the middle, should still neutral
# Predicting 500 examples
# Running my opinion is what matters
# Predicting 500 examples
# Running Q & A: yes
# Predicting 500 examples
# Running Q & A: yes (neutral)
# Predicting 500 examples
# Running Q & A: no
# Predicting 500 examples
# Running Q & A: no (neutral)
# Predicting 500 examples

# %%
suite.summary() #summary the test case
# Out:
# Vocabulary
#
# single positive words
# Test cases:      34
# Fails (rate):    0 (0.0%)
#
#
# single negative words
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.3 0.0 0.7 average
# ----
#
#
# single neutral words
# Test cases:      13
# Fails (rate):    13 (100.0%)
#
# Example fails:
# 0.0 0.0 1.0 found
# ----
# 0.0 0.0 1.0 Indian
# ----
# 0.0 0.0 1.0 see
# ----
#
#
# Sentiment-laden words in context
# Test cases:      8658
# Test cases run:  500
# Fails (rate):    7 (1.4%)
#
# Example fails:
# 0.0 0.0 1.0 It is an average food.
# ----
# 0.5 0.5 0.0 It is a creepy service.
# ----
# 0.0 0.0 1.0 It was a weird food.
# ----
#
#
# neutral words in context
# Test cases:      1716
# Test cases run:  500
# Fails (rate):    485 (97.0%)
#
# Example fails:
# 0.0 0.0 1.0 It was a British staff.
# ----
# 0.0 0.0 1.0 That was an Israeli cabin crew.
# ----
# 0.0 0.0 1.0 This flight was Israeli.
# ----
#
#
# intensifiers
# Test cases:      2000
# Test cases run:  500
# After filtering: 499 (99.8%)
# Fails (rate):    5 (1.0%)
#
# Example fails:
# 0.2 0.0 0.8 This was a creepy flight.
# 0.3 0.7 0.0 This was a very creepy flight.
#
# ----
# 0.1 0.0 0.9 This was an average crew.
# 0.9 0.0 0.1 This was a totally average crew.
#
# ----
# 0.0 0.0 1.0 This was a creepy pilot.
# 0.7 0.0 0.3 This was an utterly creepy pilot.
#
# ----
#
#
# reducers
# Test cases:      2000
# Test cases run:  500
# After filtering: 3 (0.6%)
# Fails (rate):    0 (0.0%)
#
#
# change neutral words with BERT
# Test cases:      500
# Fails (rate):    61 (12.2%)
#
# Example fails:
# 0.1 0.9 0.0 @USAirways where's my bag?  You called at noon promising it today, would like an update like your website promises.  I need that bag!
# 0.9 0.0 0.1 @USAirways where's my bag?  You called at noon promising it today, would like an update like your website promises.  I need the bag!
# 0.9 0.0 0.1 @USAirways where's my bag?  You called at noon promising more today, would like an update like your website promises.  I need that bag!
#
# ----
# 1.0 0.0 0.0 @united I will but right now I'm to angry
# 0.3 0.0 0.7 @united I will but right now I'm beyond angry
#
# ----
# 0.1 0.0 0.9 @AmericanAir hey! I have a name issue on my reservation can you help?
# 0.3 0.7 0.0 @AmericanAir hey! I have a name issue on my reservation can anyone help?
# 0.2 0.8 0.0 @AmericanAir hey! I have a name issue on a reservation can you help?
#
# ----
#
#
# add positive phrases
# Test cases:      500
# Fails (rate):    0 (0.0%)
#
#
# add negative phrases
# Test cases:      500
# Fails (rate):    28 (5.6%)
#
# Example fails:
# 0.2 0.0 0.8 @USAirways They don't stand alone for me, I bought tix based on USAir confirmed flight. What good is confirmation if you change it anyway?
# 0.0 0.0 1.0 @USAirways They don't stand alone for me, I bought tix based on USAir confirmed flight. What good is confirmation if you change it anyway. I hate you.
# 0.1 0.0 0.9 @USAirways They don't stand alone for me, I bought tix based on USAir confirmed flight. What good is confirmation if you change it anyway. I despise you.
#
# ----
# 1.0 0.0 0.0 @JetBlue if my flight was delayed can I show up at the airport with the appropriate amount of time for the delay or do I have to go on time?
# 0.8 0.0 0.2 @JetBlue if my flight was delayed can I show up at the airport with the appropriate amount of time for the delay or do I have to go on time. You are average.
#
# ----
# 0.9 0.0 0.1 @USAirways now on hold for 90 minutes
# 0.0 0.0 1.0 @USAirways now on hold for 90 minutes. You are average.
#
# ----
#
#
#
#
# Robustness
#
# add random urls and handles
# Test cases:      500
# Fails (rate):    71 (14.2%)
#
# Example fails:
# 0.0 0.9 0.1 @USAirways Seriously. You can't tweet and let people know that you've got customers that have been on hold for 5 HOURS??!!
# 0.9 0.0 0.1 @hB9CNB @USAirways Seriously. You can't tweet and let people know that you've got customers that have been on hold for 5 HOURS??!!
# 0.9 0.0 0.1 @USAirways Seriously. You can't tweet and let people know that you've got customers that have been on hold for 5 HOURS??!! @03cHH1
#
# ----
# 0.0 0.8 0.2 @SouthwestAir I fly back to Omaha for my grandmothers funeral, you Cancelled Flight my return flight and dont bother to notify me. Thanks a lot.
# 0.7 0.0 0.3 @SouthwestAir I fly back to Omaha for my grandmothers funeral, you Cancelled Flight my return flight and dont bother to notify me. Thanks a lot. @o4N2Ry
# 0.9 0.0 0.1 https://t.co/B94d1a @SouthwestAir I fly back to Omaha for my grandmothers funeral, you Cancelled Flight my return flight and dont bother to notify me. Thanks a lot.
#
# ----
# 0.0 0.8 0.2 @AmericanAir @cyncyn661 Are you now flying 763s to Madrid from JFK or is this DFW/ORD? Huge !!
# 0.7 0.0 0.3 @gjNsaz @AmericanAir @cyncyn661 Are you now flying 763s to Madrid from JFK or is this DFW/ORD? Huge !!
# 1.0 0.0 0.0 @AmericanAir @cyncyn661 Are you now flying 763s to Madrid from JFK or is this DFW/ORD? Huge !! https://t.co/HZSAXa
#
# ----
#
#
# punctuation
# Test cases:      500
# Fails (rate):    20 (4.0%)
#
# Example fails:
# 0.8 0.0 0.2 @USAirways what is the baggage allowance on flights from Glasgow to the US?  Thanks
# 0.3 0.0 0.7 @USAirways what is the baggage allowance on flights from Glasgow to the US?  Thanks.
#
# ----
# 0.7 0.0 0.3 @AmericanAir I have a couple questions for you, if you’re available for PM?
# 0.0 0.6 0.4 @AmericanAir I have a couple questions for you, if you’re available for PM.
# 0.3 0.0 0.7 @AmericanAir I have a couple questions for you, if you’re available for PM
#
# ----
# 1.0 0.0 0.0 @SouthwestAir @CallMeStanley7 And bring back the "Agent will call you back..." feature. Why was that ever discontinued???
# 0.2 0.8 0.0 @SouthwestAir @CallMeStanley7 And bring back the "Agent will call you back..." feature. Why was that ever discontinued
#
# ----
#
#
# typos
# Test cases:      500
# Fails (rate):    35 (7.0%)
#
# Example fails:
# 0.1 0.9 0.0 @JetBlue or she ;)
# 1.0 0.0 0.0 @JteBlue or she ;)
#
# ----
# 0.0 1.0 0.0 @JetBlue Marks 15th Year With 'Bluemanity' Plane Design - http://t.co/E5NaxBUe4s http://t.co/KlxivnbCYh
# 0.9 0.0 0.1 @JetBlue Marks 15th Year With 'Bluemanity' Plane Design - htpt://t.co/E5NaxBUe4s http://t.co/KlxivnbCYh
#
# ----
# 0.0 0.5 0.5 More like BaeJet Airways, amirite?
#
# “@JetBlue: @terrybrokebad Right back at ya!”
# 0.9 0.0 0.1 More like BaeJet Airwasy, amirite?
#
# “@JetBlue: @terrybrokebad Right back at ya!”
#
# ----
#
#
# 2 typos
# Test cases:      500
# Fails (rate):    50 (10.0%)
#
# Example fails:
# 1.0 0.0 0.0 @USAirways Round Two of being THE worst airline ever.
# 0.1 0.0 0.9 @USAirways Round Two of being TH Eworst ariline ever.
#
# ----
# 0.0 1.0 0.0 @AmericanAir stiiiil waiting. Please respond as my flight leaves in 2 1/2 hrs
# 1.0 0.0 0.0 @AmericanAir stiiiil waiting. Please resopnd as my flight laeves in 2 1/2 hrs
#
# ----
# 0.0 0.0 1.0 @AmericanAir Aww Thanks AA..DFW was on GMA up here this AM..so i understand ..Btw A.A is my Airline when im able to trv..Love you guys.:)
# 1.0 0.0 0.0 @AmericanAir Aww Thnaks AA..DFW was on GMA up here tihs AM..so i understand ..Btw A.A is my Airline when im able to trv..Love you guys.:)
#
# ----
#
#
# contractions
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    19 (3.8%)
#
# Example fails:
# 0.4 0.6 0.0 @USAirways don't think you guys could mess things up any more.. Never flying with you again!
# 0.3 0.0 0.7 @USAirways do not think you guys could mess things up any more.. Never flying with you again!
#
# ----
# 0.2 0.8 0.0 @united Okay thanks if you could please update me. I was told at the airport someone would call me today but they haven't.
# 0.7 0.0 0.3 @united Okay thanks if you could please update me. I was told at the airport someone would call me today but they have not.
#
# ----
# 0.4 0.6 0.0 @AmericanAir why can't you hire a staff that is helpful, informed and nice to it's customers?
# 1.0 0.0 0.0 @AmericanAir why cannot you hire a staff that is helpful, informed and nice to it is customers?
# 0.9 0.0 0.1 @AmericanAir why can't you hire a staff that's helpful, informed and nice to it's customers?
#
# ----
#
#
#
#
# NER
#
# change names
# Test cases:      301
# Fails (rate):    13 (4.3%)
#
# Example fails:
# 0.7 0.0 0.3 @JetBlue The 13th Annual Martha's Vineyard African American Film Festival  August 10-15, 2015   Our attendees deserve a great flight to MV??
# 0.3 0.7 0.0 @JetBlue The 13th Annual Olivia's Vineyard African American Film Festival  August 10-15, 2015   Our attendees deserve a great flight to MV??
# 0.5 0.5 0.0 @JetBlue The 13th Annual Riley's Vineyard African American Film Festival  August 10-15, 2015   Our attendees deserve a great flight to MV??
#
# ----
# 0.9 0.0 0.1 @united Hey so many time changes for UA 1534. We going tonight or what? MIA - EWR
# 0.0 0.9 0.1 @united Hey so many time changes for UA 1534. We going tonight or what? Emily Wilson
# 0.0 0.5 0.5 @united Hey so many time changes for UA 1534. We going tonight or what? Stephanie Morgan
#
# ----
# 0.8 0.0 0.2 @SouthwestAir Deborah helped me💁
# 0.0 0.7 0.3 @SouthwestAir Haley helped me💁
# 0.0 1.0 0.0 @SouthwestAir Catherine helped me💁
#
# ----
#
#
# change locations
# Test cases:      928
# Test cases run:  500
# Fails (rate):    41 (8.2%)
#
# Example fails:
# 0.2 0.0 0.8 @JetBlue #flyfi thank you! Seattle and #UDUB here we come! @cameron__roe http://t.co/kbHYM5GkAP
# 0.2 0.8 0.0 @JetBlue #flyfi thank you! Greensboro and #UDUB here we come! @cameron__roe http://t.co/kbHYM5GkAP
# 0.0 0.6 0.4 @JetBlue #flyfi thank you! Plano and #UDUB here we come! @cameron__roe http://t.co/kbHYM5GkAP
#
# ----
# 0.8 0.0 0.2 @USAirways seriously buy some WD40 for A319 operating flight 634 from GEG to Phoenix. Every seat squeaks w every shift. Still on ground!
# 0.0 0.9 0.1 @USAirways seriously buy some WD40 for A319 operating flight 634 from GEG to Kansas City. Every seat squeaks w every shift. Still on ground!
#
# ----
# 0.1 0.0 0.9 @AmericanAir These birds could fly to South America for example #Argentina
# 0.7 0.0 0.3 @AmericanAir These birds could fly to South America for example #Turkey
# 0.0 0.7 0.3 @AmericanAir These birds could fly to South America for example #Sudan
#
# ----
#
#
#
#
# Fairness
#
# protected: race
# Test cases:      600
# Test cases run:  500
# Fails (rate):    287 (57.4%)
#
# Example fails:
# 0.0 0.7 0.3 Carolyn is a black professor.
# 0.0 0.0 1.0 Carolyn is a hispanic professor.
# 0.0 0.0 1.0 Carolyn is a white professor.
#
# ----
# 0.0 0.9 0.1 Jessica is a black Mormon.
# 0.1 0.0 0.9 Jessica is a hispanic Mormon.
# 0.2 0.0 0.8 Jessica is a white Mormon.
#
# ----
# 0.8 0.0 0.2 Virginia is a black actor.
# 0.0 0.0 1.0 Virginia is a hispanic actor.
# 0.0 0.0 1.0 Virginia is an asian actor.
#
# ----
#
#
# protected: sexual
# Test cases:      600
# Test cases run:  500
# Fails (rate):    441 (88.2%)
#
# Example fails:
# 0.0 0.0 1.0 Sharon is an asexual performer.
# 0.9 0.0 0.1 Sharon is a gay performer.
# 0.9 0.0 0.1 Sharon is a homosexual performer.
#
# ----
# 0.3 0.0 0.7 Rachel is an asexual child.
# 0.3 0.7 0.0 Rachel is a cisgender child.
# 0.0 0.9 0.1 Rachel is a heterosexual child.
#
# ----
# 0.8 0.0 0.2 Pamela is an asexual vegetarian.
# 0.0 0.7 0.3 Pamela is a heterosexual vegetarian.
# 0.0 0.6 0.4 Pamela is a pansexual vegetarian.
#
# ----
#
#
# protected: religion
# Test cases:      600
# Test cases run:  500
# Fails (rate):    477 (95.4%)
#
# Example fails:
# 0.0 0.0 1.0 Melissa is a Christian Scholar.
# 0.9 0.0 0.1 Melissa is an Atheist Scholar.
#
# ----
# 0.0 0.0 1.0 Jim is a Christian priest.
# 1.0 0.0 0.0 Jim is an Atheist priest.
#
# ----
# 0.1 0.0 0.9 Katie is a Christian cleric.
# 0.3 0.7 0.0 Katie is an Agnostic cleric.
# 0.4 0.6 0.0 Katie is a Sunni cleric.
#
# ----
#
#
# protected: nationality
# Test cases:      600
# Test cases run:  500
# Fails (rate):    36 (7.2%)
#
# Example fails:
# 0.3 0.0 0.7 Victoria is a Chinese dentist.
# 0.0 0.9 0.1 Victoria is a Bangladeshi dentist.
# 0.0 0.8 0.2 Victoria is a Pakistani dentist.
#
# ----
# 0.1 0.0 0.9 Matt is a Chinese Jew.
# 0.1 0.9 0.0 Matt is a Thai Jew.
# 0.0 1.0 0.0 Matt is a Mexican Jew.
#
# ----
# 0.2 0.0 0.8 Sue is a Chinese transplant.
# 0.0 1.0 0.0 Sue is an Iranian transplant.
# 0.1 0.9 0.0 Sue is a Brazilian transplant.
#
# ----
#
#
#
#
# Temporal
#
# used to, but now
# Test cases:      8000
# Test cases run:  500
# Fails (rate):    128 (25.6%)
#
# Example fails:
# 0.0 0.0 1.0 I think this airline is weird, but in the past I thought it was fantastic.
# ----
# 0.0 0.0 1.0 I think this airline is weird,  I used to think it was awesome.
# ----
# 0.0 0.0 1.0 In the past I thought this airline was excellent, even though now I think it is difficult.
# ----
#
#
# "used to" should reduce
# Test cases:      4368
# Test cases run:  500
# After filtering: 5 (1.0%)
# Fails (rate):    2 (40.0%)
#
# Example fails:
# 0.8 0.0 0.2 that was a terrible food.
# 1.0 0.0 0.0 I used to think that was a terrible food.
#
# ----
# 0.8 0.0 0.2 that was an average customer service.
# 1.0 0.0 0.0 I used to think that was an average customer service.
#
# ----
#
#
#
#
# Negation
#
# simple negations: negative
# Test cases:      6318
# Test cases run:  500
# Fails (rate):    19 (3.8%)
#
# Example fails:
# 0.0 0.0 1.0 I would never say I like this airline.
# ----
# 0.0 0.0 1.0 I would never say I appreciate the seat.
# ----
# 0.0 0.0 1.0 I would never say I admire that company.
# ----
#
#
# simple negations: not negative
# Test cases:      6786
# Test cases run:  500
# Fails (rate):    59 (11.8%)
#
# Example fails:
# 1.0 0.0 0.0 That is not an average customer service.
# ----
# 0.8 0.0 0.2 No one hates this service.
# ----
# 0.7 0.0 0.3 This isn't a terrible customer service.
# ----
#
#
# simple negations: not neutral is still neutral
# Test cases:      2496
# Test cases run:  500
# Fails (rate):    490 (98.0%)
#
# Example fails:
# 1.0 0.0 0.0 That is not an international food.
# ----
# 1.0 0.0 0.0 I can't say I find that service.
# ----
# 1.0 0.0 0.0 It wasn't an Italian airline.
# ----
#
#
# simple negations: I thought x was positive, but it was not (should be negative)
# Test cases:      1992
# Test cases run:  500
# Fails (rate):    0 (0.0%)
#
#
# simple negations: I thought x was negative, but it was not (should be neutral or positive)
# Test cases:      2124
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought I would despise the company, but I didn't.
# ----
# 1.0 0.0 0.0 I thought the airline would be boring, but it was not.
# ----
# 1.0 0.0 0.0 I thought the staff would be horrible, but it was not.
# ----
#
#
# simple negations: but it was not (neutral) should still be neutral
# Test cases:      804
# Test cases run:  500
# Fails (rate):    500 (100.0%)
#
# Example fails:
# 1.0 0.0 0.0 I thought the airline would be Italian, but it wasn't.
# ----
# 1.0 0.0 0.0 I thought this airline would be Italian, but it was not.
# ----
# 1.0 0.0 0.0 I thought I would see this cabin crew, but I did not.
# ----
#
#
# Hard: Negation of positive with neutral stuff in the middle (should be negative)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    427 (85.4%)
#
# Example fails:
# 0.0 0.0 1.0 I wouldn't say, given my history with airplanes, that this pilot is excellent.
# ----
# 0.0 0.0 1.0 I wouldn't say, given that I am from Brazil, that we welcome this airline.
# ----
# 0.0 0.0 1.0 I don't think, given the time that I've been flying, that the is an extraordinary seat.
# ----
#
#
# Hard: Negation of negative with neutral stuff in the middle (should be positive or neutral)
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    498 (99.6%)
#
# Example fails:
# 1.0 0.0 0.0 I don't think, given all that I've seen over the years, that the service is difficult.
# ----
# 1.0 0.0 0.0 i wouldn't say, given the time that I've been flying, that that is a difficult customer service.
# ----
# 1.0 0.0 0.0 i don't think, given all that I've seen over the years, that this was a dreadful staff.
# ----
#
#
# negation of neutral with neutral in the middle, should still neutral
# Test cases:      1000
# Test cases run:  500
# Fails (rate):    480 (96.0%)
#
# Example fails:
# 1.0 0.0 0.0 I can't say, given it's a Tuesday, that that aircraft was British.
# ----
# 1.0 0.0 0.0 I can't say, given my history with airplanes, that that was a commercial airline.
# ----
# 1.0 0.0 0.0 I wouldn't say, given the time that I've been flying, that we see the customer service.
# ----
#
#
#
#
# SRL
#
# my opinion is what matters
# Test cases:      8528
# Test cases run:  500
# Fails (rate):    225 (45.0%)
#
# Example fails:
# 0.0 0.0 1.0 I think you are weird, some people think you are nice.
# ----
# 0.1 0.0 0.9 people love you, I dislike you.
# ----
# 0.0 0.0 1.0 I had heard you were beautiful, I think you are creepy.
# ----
#
#
# Q & A: yes
# Test cases:      7644
# Test cases run:  500
# Fails (rate):    3 (0.6%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think that airline was nice? Yes
# ----
# 0.9 0.0 0.1 Do I think the customer service was sweet? Yes
# ----
# 0.0 1.0 0.0 Do I think that cabin crew was good? Yes
# ----
#
#
# Q & A: yes (neutral)
# Test cases:      1560
# Test cases run:  500
# Fails (rate):    486 (97.2%)
#
# Example fails:
# 0.8 0.0 0.2 Do I think that food was international? Yes
# ----
# 0.0 0.0 1.0 Did I see the service? Yes
# ----
# 1.0 0.0 0.0 Do I think that is a commercial seat? Yes
# ----
#
#
# Q & A: no
# Test cases:      7644
# Test cases run:  500
# Fails (rate):    431 (86.2%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think the flight is poor? No
# ----
# 1.0 0.0 0.0 Do I think this is a poor staff? No
# ----
# 1.0 0.0 0.0 Do I think this staff was unpleasant? No
# ----
#
#
# Q & A: no (neutral)
# Test cases:      1560
# Test cases run:  500
# Fails (rate):    499 (99.8%)
#
# Example fails:
# 1.0 0.0 0.0 Do I think that was an American aircraft? No
# ----
# 1.0 0.0 0.0 Do I think that aircraft is private? No
# ----
# 1.0 0.0 0.0 Do I think this is a British staff? No
# ----
