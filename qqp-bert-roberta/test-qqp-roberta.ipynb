# %% [markdown]
# # QQP test with RoBERTa
#
# this one is used to test the performance of the RoBERTa model which is `JeremiahZ/roberta-base-mrpc` model on the QQP dataset. It involves loading the pre-trained RoBERTa model, running it on the test data, and analyzing the outcomes.

# %% [markdown]
# ## Installation

# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.test_suite import TestSuite
import numpy as np
import spacy
from checklist.perturb import Perturb

# %% [markdown]
# ## Import the model

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

tokenizer = AutoTokenizer.from_pretrained("JeremiahZ/roberta-base-mrpc")
model = AutoModelForSequenceClassification.from_pretrained("JeremiahZ/roberta-base-mrpc")
model.eval()
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
# used to decrease size of chunk
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
# use to process the data with the RoBERTa model
def batch_qqp(data, batch_size=128):
    ret = []
    for d in chunks(data, batch_size):
        t = tokenizer([a[0] for a in d], [a[1] for a in d], return_tensors='pt', padding=True)
        with torch.no_grad():
            logits = torch.softmax(model(**t)[0], dim=1).numpy() #apply with RoBERTa model
        ret.append(logits)
    return np.vstack(ret)

# %%
from checklist.pred_wrapper import PredictorWrapper
# wrapped_pp returns a tuple with (predictions, softmax confidences)
wrapped_pp = PredictorWrapper.wrap_softmax(batch_qqp) #to make sure that the output of the function will be formatted

# %%
# Test
s0 = "The restaurant 'Haidilao' serves chinese hotpot."
s1 = "Mala soup is very delicious"
s2 = "Located in wide area, Haidilao is known for good services."
batch_qqp([(s0, s1), (s0, s2)])
# Out:
# array([[0.9924535 , 0.00754646],
#        [0.99132866, 0.0086714 ]], dtype=float32)

# %%
suite_path = 'qqp_suite.pkl' #define path of the pkl
suite = TestSuite.from_file(suite_path)

# %%
#run the test with 10 test case. I have tried or n=100. It spend time for many hours .....
# overwrite = True which meant write over the old file
suite.run(wrapped_pp, n=10, overwrite=True)
# Out:
# Running Modifier: adj
# Predicting 10 examples
# Running different adjectives
# Predicting 10 examples
# Running Different animals
# Predicting 10 examples
# Running Irrelevant modifiers - animals
# Predicting 10 examples
# Running Irrelevant modifiers - people
# Predicting 10 examples
# Running Irrelevant preamble with different examples.
# Predicting 10 examples
# Running Preamble is relevant (different injuries)
# Predicting 10 examples
# Running How can I become more {synonym}?
# Predicting 10 examples
# Running (question, f(question)) where f(question) replaces synonyms?
# Predicting 10 examples
# Running Replace synonyms in real pairs
# Predicting 30 examples
# Running How can I become more X != How can I become less X
# Predicting 10 examples
# Running How can I become more X = How can I become less antonym(X)
# Predicting 10 examples
# Running add one typo
# Predicting 30 examples
# Running contrations
# Predicting 28 examples
# Running (q, paraphrase(q))
# Predicting 964 examples
# Running Product of paraphrases(q1) * paraphrases(q2)
# Predicting 990 examples
# Running same adjectives, different people
# Predicting 10 examples
# Running same adjectives, different people v2
# Predicting 10 examples
# Running same adjectives, different people v3
# Predicting 10 examples
# Running Change same name in both questions
# Predicting 110 examples
# Running Change same location in both questions
# Predicting 83 examples
# Running Change same number in both questions
# Predicting 101 examples
# Running Change first name in one of the questions
# Predicting 190 examples
# Running Change first and last name in one of the questions
# Predicting 210 examples
# Running Change location in one of the questions
# Predicting 196 examples
# Running Change numbers in one of the questions
# Predicting 206 examples
# Running Keep entitites, fill in with gibberish
# Predicting 95 examples
# Running Is person X != Did person use to be X
# Predicting 10 examples
# Running Is person X != Is person becoming X
# Predicting 10 examples
# Running What was person's life before becoming X != What was person's life after becoming X
# Predicting 10 examples
# Running Do you have to X your dog before Y it != Do you have to X your dog after Y it.
# Predicting 10 examples
# Running Is it {ok, dangerous, ...} to {smoke, rest, ...} after != before
# Predicting 10 examples
# Running How can I become a X person != How can I become a person who is not X
# Predicting 10 examples
# Running Is it {ok, dangerous, ...} to {smoke, rest, ...} in country != Is it {ok, dangerous, ...} not to {smoke, rest, ...} in country
# Predicting 10 examples
# Running What are things a {noun} should worry about != should not worry about.
# Predicting 10 examples
# Running How can I become a X person == How can I become a person who is not antonym(X)
# Predicting 10 examples
# Running Simple coref: he and she
# Predicting 10 examples
# Running Simple coref: his and her
# Predicting 10 examples
# Running Who do X think - Who is the ... according to X
# Predicting 10 examples
# Running Order does not matter for comparison
# Predicting 30 examples
# Running Order does not matter for symmetric relations
# Predicting 10 examples
# Running Order does matter for asymmetric relations
# Predicting 10 examples
# Running traditional SRL: active / passive swap
# Predicting 10 examples
# Running traditional SRL: wrong active / passive swap
# Predicting 10 examples
# Running traditional SRL: active / passive swap with people
# Predicting 10 examples
# Running traditional SRL: wrong active / passive swap with people
# Predicting 10 examples
# Running A or B is not the same as C and D
# Predicting 10 examples
# Running A or B is not the same as A and B
# Predicting 10 examples
# Running A and / or B is the same as B and / or A
# Predicting 10 examples
# Running a {nationality} {profession} = a {profession} and {nationality}
# Predicting 10 examples
# Running Reflexivity: (q, q) should be duplicate
# Predicting 10 examples
# Running Symmetry: f(a, b) = f(b, a)
# Predicting 20 examples
# Running Testing implications
# Predicting 30 examples

# %%
suite.summary() #summary the test case
# Out:
# Vocabulary
#
# Modifier: adj
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Elizabeth Miller an intern?', 'Is Elizabeth Miller a good intern?')
# ----
# 1.0 ('Is Albert Brooks a secretary?', 'Is Albert Brooks an exceptional secretary?')
# ----
# 1.0 ('Is Amanda Thomas an actor?', 'Is Amanda Thomas a good actor?')
# ----
#
#
# different adjectives
# Test cases:      963
# Test cases run:  10
# Fails (rate):    6 (60.0%)
#
# Example fails:
# 0.9 ('Is Sarah Harrison gay?', 'Is Sarah Harrison trustworthy?')
# ----
# 0.6 ('Is Rachel Sullivan gay?', 'Is Rachel Sullivan famous?')
# ----
# 0.9 ('Is Emma Robertson white?', 'Is Emma Robertson mad?')
# ----
#
#
# Different animals
# Test cases:      942
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Can I feed my turtle chocolate?', 'Can I feed my rabbit chocolate?')
# ----
# 1.0 ('Can I feed my rabbit cookies?', 'Can I feed my turtle cookies?')
# ----
# 1.0 ('Can I feed my goat insulin?', 'Can I feed my rat insulin?')
# ----
#
#
# Irrelevant modifiers - animals
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Irrelevant modifiers - people
# Test cases:      995
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Irrelevant preamble with different examples.
# Test cases:      952
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Preamble is relevant (different injuries)
# Test cases:      975
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('I hurt my elbow last time I played football. Should I never play again?', 'I hurt my bone last time I played football. Should I never play again?')
# ----
# 1.0 ('I hurt my leg last time I played football. Is this going to impact my performance?', 'I hurt my shoulder last time I played football. Is this going to impact my performance?')
# ----
# 1.0 ('I hurt my wrist last time I played football. Should I never play again?', 'I hurt my teeth last time I played football. Should I never play again?')
# ----
#
#
# How can I become more X != How can I become less X
# Test cases:      2000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('How can I become less patient?', 'How can I become more patient?')
# ----
# 1.0 ('How can I become more pessimistic?', 'How can I become less pessimistic?')
# ----
# 1.0 ('How can I become less polite?', 'How can I become more polite?')
# ----
#
#
#
#
# Taxonomy
#
# How can I become more {synonym}?
# Test cases:      6000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# (question, f(question)) where f(question) replaces synonyms?
# Test cases:      326
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Replace synonyms in real pairs
# Test cases:      251
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# How can I become more X = How can I become less antonym(X)
# Test cases:      2000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
#
#
# Robustness
#
# add one typo
# Test cases:      500
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# contrations
# Test cases:      500
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# (q, paraphrase(q))
# Test cases:      200
# Test cases run:  10
# Fails (rate):    3 (30.0%)
#
# Example fails:
# 1.0 ('How do I become rich?', 'How do I become rich?')
# 0.0 ('If you want to become rich, what should you do?', 'How can I become rich?')
# 0.0 ('If you want to become rich, what should you do?', 'How can you become rich?')
#
# ----
# 1.0 ('How do I lose 30 pounds?', 'How do I lose 30 pounds?')
# 0.0 ('If I want to lose 30 pounds, what should I do?', 'How do you lose 30 pounds?')
# 0.0 ('If I want to lose 30 pounds, what should I do?', 'How can you lose 30 pounds?')
#
# ----
# 1.0 ('How do I loose weight fast?', 'How do I loose weight fast?')
# 0.0 ('If I want to loose weight fast, what should I do?', 'How can you loose weight fast?')
# 0.0 ('If I want to loose weight fast, what should I do?', 'How do you loose weight fast?')
#
# ----
#
#
# Product of paraphrases(q1) * paraphrases(q2)
# Test cases:      100
# Test cases run:  10
# Fails (rate):    6 (60.0%)
#
# Example fails:
# 0.0 ('How can I detox from meth quickly?', 'How can I prevent champagne from going bad too quickly?')
# 1.0 ('In order to detox from meth quickly, what should you do?', 'In order to prevent champagne from going bad too quickly, what should I do?')
# 1.0 ('In order to detox from meth quickly, what should I do?', 'In order to prevent champagne from going bad too quickly, what should I do?')
#
# ----
# 1.0 ('How can I know that my girlfriend is lying?', 'How can I tell if my girlfriend is cheating on me?')
# 0.0 ('If I want to know that my girlfriend is lying, what should I do?', 'What is a good way to tell if your girlfriend is cheating on me?')
# 0.0 ('If I want to know that my girlfriend is lying, what should I do?', 'How can you tell if your girlfriend is cheating on me?')
#
# ----
# 1.0 ('How do I become rich?', 'How do I get rich?')
# 0.0 ('If you want to become rich, what should you do?', 'How can I get rich?')
# 0.0 ('If you want to become rich, what should you do?', 'How can you get rich?')
#
# ----
#
#
#
#
# NER
#
# same adjectives, different people
# Test cases:      989
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# same adjectives, different people v2
# Test cases:      996
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Matthew Williams Muslim?', 'Is Robin Williams Muslim?')
# ----
# 1.0 ('Is Ellen Evans racist?', 'Is Christopher Evans racist?')
# ----
# 1.0 ('Is Kathryn Cooper famous?', 'Is Mark Cooper famous?')
# ----
#
#
# same adjectives, different people v3
# Test cases:      987
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Emily Anderson an anarchist?', 'Is Emily Martin an anarchist?')
# ----
# 1.0 ('Is Catherine Bennett an immigrant?', 'Is Catherine Hart an immigrant?')
# ----
# 1.0 ('Is Simon Gordon Muslim?', 'Is Simon Hunter Muslim?')
# ----
#
#
# Change same name in both questions
# Test cases:      500
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Change same location in both questions
# Test cases:      500
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Change same number in both questions
# Test cases:      500
# Test cases run:  10
# Fails (rate):    1 (10.0%)
#
# Example fails:
# 0.0 ('How can changing 500 and 1000 rupee notes end the black money in India?', 'How effective is scrapping 500 and 1000 rupee notes? Will it reduce black money?')
# 1.0 ('How can changing 408 and 1000 rupee notes end the black money in India?', 'How effective is scrapping 408 and 1000 rupee notes? Will it reduce black money?')
# 1.0 ('How can changing 463 and 1000 rupee notes end the black money in India?', 'How effective is scrapping 463 and 1000 rupee notes? Will it reduce black money?')
#
# ----
#
#
# Change first name in one of the questions
# Test cases:      500
# Test cases run:  10
# After filtering: 7 (70.0%)
# Fails (rate):    6 (85.7%)
#
# Example fails:
# 1.0 ('Is it possible to vote for anyone other than Hillary Clinton and Donald Trump?', 'In the November 2016 presidential election, can an American citizen vote for anyone other than Hillary Clinton or Donald Trump?')
# 1.0 ('Is it possible to vote for anyone other than Hillary Clinton and Donald Trump?', 'In the November 2016 presidential election, can an American citizen vote for anyone other than Hillary Clinton or Travis Trump?')
# 1.0 ('Is it possible to vote for anyone other than Hillary Clinton and Donald Trump?', 'In the November 2016 presidential election, can an American citizen vote for anyone other than Vanessa Clinton or Donald Trump?')
#
# ----
# 1.0 ('How did Donald Trump win the Presidential election?', 'How did Donald Trump win the election?')
# 1.0 ('How did Lucas Trump win the Presidential election?', 'How did Donald Trump win the election?')
# 1.0 ('How did Derek Trump win the Presidential election?', 'How did Donald Trump win the election?')
#
# ----
# 1.0 ('Who is better Donald Trump or Hillary Clinton?', 'Which presidential candidate is better: Trump or Clinton?')
# 1.0 ('Who is better Donald Trump or Hillary Clinton?', 'Which presidential candidate is better: Trump or Elijah?')
# 1.0 ('Who is better Donald Trump or Hillary Clinton?', 'Which presidential candidate is better: Trump or Jeremiah?')
#
# ----
#
#
# Change first and last name in one of the questions
# Test cases:      714
# Test cases run:  10
# After filtering: 5 (50.0%)
# Fails (rate):    3 (60.0%)
#
# Example fails:
# 1.0 ('What is your favorite song performed, written, and/or performed by Michael Jackson?', "What's your favorite Michael Jackson song and why?")
# 1.0 ('What is your favorite song performed, written, and/or performed by Michael Jackson?', "What's your favorite Michael Butler song and why?")
# 1.0 ('What is your favorite song performed, written, and/or performed by Michael Butler?', "What's your favorite Michael Jackson song and why?")
#
# ----
# 1.0 ('If you could sit down for a coffee with Tim Cook, what would you ask him?', 'If you had 15 minutes with Apple CEO Tim Cook what would you ask him?')
# 0.5 ('If you could sit down for a coffee with Christopher Watson, what would you ask him?', 'If you had 15 minutes with Apple CEO Tim Cook what would you ask him?')
#
# ----
# 1.0 ("What if Adam and Eve didn't eat of the tree of good and evil?", "What if Adam and Eve didn't eat the apple?")
# 1.0 ("What if Sean and Eve didn't eat of the tree of good and evil?", "What if Adam and Eve didn't eat the apple?")
# 1.0 ("What if Brandon and Eve didn't eat of the tree of good and evil?", "What if Adam and Eve didn't eat the apple?")
#
# ----
#
#
# Change location in one of the questions
# Test cases:      1385
# Test cases run:  10
# After filtering: 5 (50.0%)
# Fails (rate):    5 (100.0%)
#
# Example fails:
# 1.0 ("What does Germany look like, and how does its geography compare to Sweden's?", "What does Germany look like, and how does its geography compare to Hungary's?")
# 1.0 ("What does Tanzania look like, and how does its geography compare to Sweden's?", "What does Germany look like, and how does its geography compare to Hungary's?")
# 1.0 ("What does Turkey look like, and how does its geography compare to Sweden's?", "What does Germany look like, and how does its geography compare to Hungary's?")
#
# ----
# 1.0 ('Why is Malaysia wealthier than Indonesia and Philippines?', 'Why is Malaysia better than the Philippines for business?')
# 1.0 ('Why is Malaysia wealthier than Indonesia and Philippines?', 'Why is Malaysia better than the Indonesia for business?')
# 1.0 ('Why is Indonesia wealthier than Indonesia and Philippines?', 'Why is Malaysia better than the Philippines for business?')
#
# ----
# 1.0 ('Are there hedge funds in India?', "Why aren't there hedge funds in India?")
# 1.0 ('Are there hedge funds in India?', "Why aren't there hedge funds in Spain?")
# 1.0 ('Are there hedge funds in China?', "Why aren't there hedge funds in India?")
#
# ----
#
#
# Change numbers in one of the questions
# Test cases:      1500
# Test cases run:  10
# After filtering: 9 (90.0%)
# Fails (rate):    8 (88.9%)
#
# Example fails:
# 1.0 ('I got 80.02 in my CAT 2015, which colleges should I apply for?', 'I have got 86.3 percentile in cat 2015, which colleges should I apply to?')
# 1.0 ('I got 80.02 in my CAT 2015, which colleges should I apply for?', 'I have got 86.3 percentile in cat 1907, which colleges should I apply to?')
# 1.0 ('I got 80.02 in my CAT 2015, which colleges should I apply for?', 'I have got 86.3 percentile in cat 1947, which colleges should I apply to?')
#
# ----
# 1.0 ('What Is your New year resolutions in 2017?', "What is your New Year's resolution for 2017?")
# 1.0 ('What Is your New year resolutions in 2017?', "What is your New Year's resolution for 1957?")
# 1.0 ('What Is your New year resolutions in 2017?', "What is your New Year's resolution for 1976?")
#
# ----
# 1.0 ('Can I use Jio in 3G phone?', 'Can I use Jio sim in 3G handset phone?')
# 1.0 ('Can I use Jio in 3G phone?', 'Can I use Jio sim in 3G handset phone?')
# 1.0 ('Can I use Jio in 3G phone?', 'Can I use Jio sim in 3G handset phone?')
#
# ----
#
#
# Keep entitites, fill in with gibberish
# Test cases:      500
# Test cases run:  10
# Fails (rate):    3 (30.0%)
#
# Example fails:
# 1.0 ('Is RNA always single stranded?', 'Is RNA single-stranded?')
# 0.6 ('Is RNA single-stranded?', 'Is this RNA?')
#
# ----
# 1.0 ('What are we going to do now that Donald Trump has won the election?', 'Now that Donald Trump is president, what will happen to America?')
# 1.0 ('Now that Donald Trump is president, what will happen to America?', 'what will Donald Trump offer America?')
# 0.8 ('Now that Donald Trump is president, what will happen to America?', 'what does Donald Trump offer America?')
#
# ----
# 0.0 ('If Obama is Christian as he claims, why does he ignore the Christians being murdered by Muslim terrorists in the Middle East and around the world?', 'How can an average student increase his concept for the JEE?')
# 1.0 ('If Obama is Christian as he claims, why does he ignore the Christians being murdered by Muslim terrorists in the Middle East and around the world?', 'why is Obama a Christian if Christians are Muslim in the Middle East?')
# 1.0 ('If Obama is Christian as he claims, why does he ignore the Christians being murdered by Muslim terrorists in the Middle East and around the world?', 'why is Obama a Christian when Christians are Muslim in the Middle East?')
#
# ----
#
#
#
#
# Temporal
#
# Is person X != Did person use to be X
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Melissa Edwards an interpreter?', 'Did Melissa Edwards use to be an interpreter?')
# ----
# 1.0 ('Is Eleanor Thomas an author?', 'Did Eleanor Thomas use to be an author?')
# ----
# 1.0 ('Is Stephanie Murray an executive?', 'Did Stephanie Murray use to be an executive?')
# ----
#
#
# Is person X != Is person becoming X
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Tony Palmer an actress?', 'Is Tony Palmer becoming an actress?')
# ----
# 1.0 ('Is Stephanie Butler an editor?', 'Is Stephanie Butler becoming an editor?')
# ----
# 1.0 ('Is Christine Turner an attorney?', 'Is Christine Turner becoming an attorney?')
# ----
#
#
# What was person's life before becoming X != What was person's life after becoming X
# Test cases:      998
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ("What was Julie Phillips's life before becoming a secretary?", "What was Julie Phillips's life after becoming a secretary?")
# ----
# 1.0 ("What was Jay Stevens's life before becoming a photographer?", "What was Jay Stevens's life after becoming a photographer?")
# ----
# 1.0 ("What was Henry Graham's life before becoming an attorney?", "What was Henry Graham's life after becoming an attorney?")
# ----
#
#
# Do you have to X your dog before Y it != Do you have to X your dog after Y it.
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Do you have to weigh your hamster before taking it?', 'Do you have to weigh your hamster after taking it?')
# ----
# 1.0 ('Do you have to examine your hamster before releasing it?', 'Do you have to examine your hamster after releasing it?')
# ----
# 1.0 ('Do you have to milk your dog before feeding it?', 'Do you have to milk your dog after feeding it?')
# ----
#
#
# Is it {ok, dangerous, ...} to {smoke, rest, ...} after != before
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is it healthy to text before 11am?', 'Is it healthy to text after 11am?')
# ----
# 1.0 ('Is it ok to drink before 10am?', 'Is it ok to drink after 10am?')
# ----
# 1.0 ('Is it ok to dance before 4pm?', 'Is it ok to dance after 4pm?')
# ----
#
#
#
#
# Negation
#
# How can I become a X person != How can I become a person who is not X
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('How can I become a like person?', 'How can I become a person who is not like?')
# ----
# 1.0 ('How can I become a single person?', 'How can I become a person who is not single?')
# ----
# 1.0 ('How can I become a troubled person?', 'How can I become a person who is not troubled?')
# ----
#
#
# Is it {ok, dangerous, ...} to {smoke, rest, ...} in country != Is it {ok, dangerous, ...} not to {smoke, rest, ...} in country
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is it wrong to dance in Ecuador?', 'Is it wrong not to dance in Ecuador?')
# ----
# 1.0 ('Is it wrong to spy in Tuvalu?', 'Is it wrong not to spy in Tuvalu?')
# ----
# 1.0 ('Is it healthy to camp in El Salvador?', 'Is it healthy not to camp in El Salvador?')
# ----
#
#
# What are things a {noun} should worry about != should not worry about.
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('What are things a journalist should worry about?', 'What are things a journalist should not worry about?')
# ----
# 1.0 ('What are things a waitress should worry about?', 'What are things a waitress should not worry about?')
# ----
# 1.0 ('What are things an investigator should worry about?', 'What are things an investigator should not worry about?')
# ----
#
#
# How can I become a X person == How can I become a person who is not antonym(X)
# Test cases:      2000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
#
#
# Coref
#
# Simple coref: he and she
# Test cases:      2000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('If Ben and Barbara were alone, do you think he would reject her?', 'If Ben and Barbara were alone, do you think she would reject him?')
# ----
# 1.0 ('If Ellen and Joseph were alone, do you think he would reject her?', 'If Ellen and Joseph were alone, do you think she would reject him?')
# ----
# 1.0 ('If Louis and Katie were alone, do you think he would reject her?', 'If Louis and Katie were alone, do you think she would reject him?')
# ----
#
#
# Simple coref: his and her
# Test cases:      2000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('If Bruce and Claire were married, would her family be happy?', "If Bruce and Claire were married, would Bruce's family be happy?")
# ----
# 1.0 ('If John and Kathy were married, would his family be happy?', "If John and Kathy were married, would Kathy's family be happy?")
# ----
# 1.0 ('If Harry and Anna were married, would his family be happy?', "If Harry and Anna were married, would Anna's family be happy?")
# ----
#
#
#
#
# SRL
#
# Who do X think - Who is the ... according to X
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Order does not matter for comparison
# Test cases:      990
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Order does not matter for symmetric relations
# Test cases:      991
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Order does matter for asymmetric relations
# Test cases:      997
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# traditional SRL: active / passive swap
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# traditional SRL: wrong active / passive swap
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Did Kathleen sell the land?', 'Was Kathleen sold by the land?')
# ----
# 1.0 ('Did Jonathan miss the island?', 'Was Jonathan missed by the island?')
# ----
# 1.0 ('Did Victoria sell the painting?', 'Was Victoria sold by the painting?')
# ----
#
#
# traditional SRL: active / passive swap with people
# Test cases:      991
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# traditional SRL: wrong active / passive swap with people
# Test cases:      997
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Does Daniel love Jeff?', 'Is Daniel loved by Jeff?')
# ----
# 1.0 ('Does Caroline believe Roger?', 'Is Caroline believed by Roger?')
# ----
# 1.0 ('Does Philip bother Laura?', 'Is Philip bothered by Laura?')
# ----
#
#
#
#
# Logic
#
# A or B is not the same as C and D
# Test cases:      826
# Test cases run:  10
# Fails (rate):    9 (90.0%)
#
# Example fails:
# 1.0 ('Is Roy Watson a nurse or an accountant?', 'Is Roy Watson simultaneously an educator and an attorney?')
# ----
# 1.0 ('Is Charlie Rogers a journalist or an assistant?', 'Is Charlie Rogers simultaneously an organizer and an artist?')
# ----
# 1.0 ('Is Fiona Gray an administrator or an investor?', 'Is Fiona Gray simultaneously an engineer and an investigator?')
# ----
#
#
# A or B is not the same as A and B
# Test cases:      975
# Test cases run:  10
# Fails (rate):    10 (100.0%)
#
# Example fails:
# 1.0 ('Is Harold Bennett an assistant or an investor?', 'Is Harold Bennett simultaneously an assistant and an investor?')
# ----
# 1.0 ('Is Lauren Brown an investigator or a DJ?', 'Is Lauren Brown simultaneously an investigator and a DJ?')
# ----
# 1.0 ('Is Helen Brown an activist or an entrepreneur?', 'Is Helen Brown simultaneously an activist and an entrepreneur?')
# ----
#
#
# A and / or B is the same as B and / or A
# Test cases:      968
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# a {nationality} {profession} = a {profession} and {nationality}
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Reflexivity: (q, q) should be duplicate
# Test cases:      1000
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Symmetry: f(a, b) = f(b, a)
# Test cases:      500
# Test cases run:  10
# Fails (rate):    0 (0.0%)
#
#
# Testing implications
# Test cases:      8328
# Test cases run:  10
# After filtering: 9 (90.0%)
# Fails (rate):    2 (22.2%)
#
# Example fails:
# 0.1 ('Why are my all questions marked for improvement?', '"How can I avoid having so many of my questions marked ""needs improvement""?"')
# 1.0 ('Why are my all questions marked for improvement?', 'Why are my logical questions marked as needing clarification?')
# 0.0 ('"How can I avoid having so many of my questions marked ""needs improvement""?"', 'Why are my logical questions marked as needing clarification?')
#
# ----
# 0.1 ('What are the easiest ways to earn money online?', 'How can I earn money part time online?')
# 1.0 ('What are the easiest ways to earn money online?', 'What is best way to make money online?')
# 1.0 ('How can I earn money part time online?', 'What is best way to make money online?')
#
# ----
